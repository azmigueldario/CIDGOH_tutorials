# %% [markdown]
# # Annotation of genomes
#
# ## Introduction to annotation tools
#
# Once we have analysis ready genomes (verified quality and lack of contamination), we can do annotation. The main goal of annotation is to identify the genomic features that are present in the contigs. There are many available tools to find these relevant sequences, and they mostly use predictive algorithms (recognition of common sequences in the DNA) or alignment against a reference database.
#
# Two of the most commonly used tools are [BAKTA](https://github.com/oschwengers/bakta)  (https://doi.org/10.1099/mgen.0.000685) and the [NCBI Prokaryotic Genome Annotation Pipeline](https://github.com/ncbi/pgap) (https://doi.org/10.1093/nar/gkaa1105).
#
# Bakta produces a comprehensive annotation of Open Reading Frames (sequences that code for amino acids over a length threshold), different types of RNA (ncRNA, tRNA, rRNA), hypothetical proteins, genes and CRISPR arrays.

# %%
# source PATH to use module function
source /cvmfs/soft.computecanada.ca/config/profile/bash.sh

# %% [markdown]
# Bakta uses a reference database that is to large for a tutorial (~30GB), so we are using a reduced database (~3.0 GB) that may produce less reliable feature annotation.
#
# The database was downloaded and decompressed into `/tools/reference_data/db-light` using the command below
# ```
# singularity exec -B /scratch,/project,/etc </PATH/TO/BAKTA/IMAGE/> \
#     bakta_db download \
#     --output </OUTPUT/DIR/> \
#     --type light
# ```

# %% [markdown]
# ## Annotation of draft genomes
#
# First, we can review the structure of our working directory.
#
# ### **Note:** Remember to have **bash_kernel** for the Jupyter notebook loaded.

# %%
# review the project structure
tree -dL 2 ~/tutorials
# Out:
# /home/jupyter-mdprieto/tutorials
# |-- raw_reads
# |-- results
# |   |-- annotation
# |   |-- assembly_checkm
# |   |-- assembly_quast
# |   |-- contigs
# |   |-- reads_qc
# |   `-- snippy
# |-- tools
# |   |-- db-light
# |   |-- reference_data
# |   `-- sing_imgs
# `-- trimmed_reads
#
# 13 directories

# %% [markdown]
# We save the path to the bakta singularity image in the following [ENVIRONMENTAL VARIABLE](https://linuxize.com/post/how-to-set-and-list-environment-variables-in-linux/) to use them in our commands

# %%
BAKTA_IMG="/mnt/cidgoh-object-storage/images/bakta_1.7.sif"

# %% [markdown]
# Now, we execute the command `bakta` specifying a single draft genome. Annotation for the remaining ones is already provided (7 min per annotation).

# %%
# remove previously produced results
rm ~/tutorials/results/annotation/ERR10479518*

singularity exec -B /etc "$BAKTA_IMG" bakta \
    --db ~/tutorials/tools/db-light                                                                `# path to bakta database` \
    ~/tutorials/results/contigs/ERR10479518_contigs.fa                              `# file to annotate`\
    --output ~/tutorials/results/annotation/                                        `# output directory` \
    --genus Pseudomonas                                                             `# specify genus of isolate` \
    --prefix $(echo "ERR10479518_contigs.fa" | grep -Eo "ERR[0-9]+")                `# prefix of sample name only for output`
# Out:
# parse genome sequences...
# 	imported: 142
# 	filtered & revised: 142
# 	contigs: 142
#
# start annotation...
# predict tRNAs...
# 	found: 63
# predict tmRNAs...
# 	found: 1
# predict rRNAs...
# 	found: 3
# predict ncRNAs...
# 	found: 53
# predict ncRNA regions...
# 	found: 39
# predict CRISPR arrays...
# 	found: 0
# predict & annotate CDSs...
# 	predicted: 6713
# 	discarded spurious: 4
# 	revised translational exceptions: 1
# 	detected IPSs: 0
# 	found PSCCs: 6107
# 	lookup annotations...
# 	conduct expert systems...
# 		amrfinder: 26
# 		protein sequences: 625
# 	combine annotations and mark hypotheticals...
# analyze hypothetical proteins: 588
# 	detected Pfam hits: 136
# 	calculated proteins statistics
# 	revise special cases...
# extract sORF...
# 	potential: 44894
# 	discarded due to overlaps: 35701
# 	discarded spurious: 0
# 	detected IPSs: 0
# 	found PSCCs: 0
# 	lookup annotations...
# 	filter and combine annotations...
# 	filtered sORFs: 0
# detect gaps...
# 	found: 0
# detect oriCs/oriVs...
# 	found: 2
# detect oriTs...
# 	found: 0
# apply feature overlap filters...
# select features and create locus tags...
# selected: 6868
# improve annotations...
# 	revised gene symbols: 9
#
# genome statistics:
# 	Genome size: 7,250,765 bp
# 	Contigs/replicons: 142
# 	GC: 65.7 %
# 	N50: 215,154
# 	N ratio: 0.0 %
# 	coding density: 88.8 %
#
# annotation summary:
# 	tRNAs: 62
# 	tmRNAs: 1
# 	rRNAs: 3
# 	ncRNAs: 53
# 	ncRNA regions: 39
# 	CRISPR arrays: 0
# 	CDSs: 6708
# 		hypotheticals: 588
# 		pseudogenes: 0
# 		signal peptides: 0
# 	sORFs: 0
# 	gaps: 0
# 	oriCs/oriVs: 2
# 	oriTs: 0
#
# export annotation results to: /home/jupyter-mdprieto/tutorials/results/annotation
# 	human readable TSV...
# 	GFF3...
# 	INSDC GenBank & EMBL...
# 	genome sequences...
# 	feature nucleotide sequences...
# 	translated CDS sequences...
# 	circular genome plot...
# 	hypothetical TSV...
# 	translated hypothetical CDS sequences...
# 	machine readable JSON...
# 	genome and annotation summary...
#
# If you use these results please cite Bakta: https://doi.org/10.1099/mgen.0.000685
# Annotation successfully finished in 4:53 [mm:ss].

# %% [markdown]
# Now, our analysis results look something like this. The directory structure now includes results from annotation and the tools directory includes a reference database to run bakta.

# %%
# project structure
tree -dL 2 ~/tutorials
# Out:
# /home/jupyter-mdprieto/tutorials
# |-- raw_reads
# |-- results
# |   |-- annotation
# |   |-- assembly_checkm
# |   |-- assembly_quast
# |   |-- contigs
# |   |-- reads_qc
# |   `-- snippy
# |-- tools
# |   |-- db-light
# |   |-- reference_data
# |   `-- sing_imgs
# `-- trimmed_reads
#
# 13 directories

# %% [markdown]
# The output of **Bakta** annotation can be found in `tutorials/results/annotation`.
#
# - Circular plots can be visualized directly on Jupyter by clicking them or downloaded to your local computer and opened.
# - Annotation results in this dataset are not ideal as we are working with draft genomes instead of complete chromosome asssemblies or scaffolds. These more refined assemblies require long reads to polish the contigs.
#
# Take a look at this paper for more information about assembly approaches: https://doi.org/10.1093/bib/bbw096.

# %% [markdown]
# # Phylogenetic tree
#
# To produce a phylogenetic tree we must compare the genomes using some kind of metric. Here, we will use **Snippy** to identify single nucleotide variants (SNV) in our genomes (https://github.com/tseemann/snippy).
#
# **Gubbins** is a tool that removes genes or features that were obtained through horizontal gene transfer and that may obscure the interpretation of the phylogenetic tree (https://github.com/nickjcroucher/gubbins).

# %%
SNIPPY_IMG="$HOME/tutorials/tools/sing_imgs/snippy_4.6.0.sif"
GUBBINS_IMG="$HOME/tutorials/tools/sing_imgs/gubbins-3.2.1.img"
REF_GENOME="$HOME/tutorials/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna"

# %% [markdown]
# **Snippy** is a relatively fast tool, so we can analyze all the genomes we have available without too much wait. We apply the tool to every available draft genome.
#
# - The recommended use for the tool is actually on raw reads.
#
# To avoid typing the same command for every draft genome, we use a [**_for loop_**](https://ryanstutorials.net/bash-scripting-tutorial/bash-loops.php) to quickly reproduce the same command for a list of contig files.

# %%
for contig in $(ls $HOME/tutorials/results/contigs/*contigs.fa)
do
    
    # define isolate name
    sample_id=$(basename "$contig" '_contigs.fa')
    echo "Processing $sample_id"

    # run snippy for each isolate
    singularity exec $SNIPPY_IMG snippy \
    --outdir $HOME/tutorials/results/snippy/$sample_id  `# save in a subdirectory`\
    --ctgs "$contig" \
    --ref $REF_GENOME \
    --cpus 8 \
    --force \
    --cleanup \
    --quiet

    # produce core genome analysis in results_snippy folder
    
    cd $HOME/tutorials/results/snippy/
    singularity exec "$SNIPPY_IMG" snippy-core --ref $REF_GENOME \
    $HOME/tutorials/results/snippy/ERR*
done
# Out:
# Processing ERR10479510
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [samclip] samclip 0.4.0 by Torsten Seemann (@torstenseemann)
# [samclip] Loading: reference/ref.fa.fai
# [samclip] Found 1 sequences in reference/ref.fa.fai
# [M::process] read 320000 sequences (80000000 bp)...
# [M::process] read 253774 sequences (63420526 bp)...
# [M::mem_process_seqs] Processed 320000 reads in 33.671 CPU sec, 4.140 real sec
# [samclip] Processed 100000 records...
# [samclip] Processed 200000 records...
# [samclip] Processed 300000 records...
# [M::mem_process_seqs] Processed 253774 reads in 29.408 CPU sec, 3.590 real sec
# [samclip] Processed 400000 records...
# [samclip] Processed 500000 records...
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa mem -Y -M -R @RG\tID:ERR10479510\tSM:ERR10479510 -t 8 reference/ref.fa fake_reads.fq
# [main] Real time: 9.783 sec; CPU: 64.325 sec
# [samclip] Total SAM records 574968, removed 9431, allowed 1610, passed 565537
# [samclip] Header contained 3 lines
# [samclip] Done.
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# normalize v0.5
#
# options:     input VCF file                                  -
#          [o] output VCF file                                 -
#          [w] sorting window size                             10000
#          [n] no fail on reference inconsistency for non SNPs false
#          [q] quiet                                           false
#          [d] debug                                           false
#          [r] reference FASTA file                            reference/ref.fa
#
#
# stats: biallelic
#           no. left trimmed                      : 57
#           no. right trimmed                     : 388
#           no. left and right trimmed            : 17
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. biallelic normalized           : 462
#
#        multiallelic
#           no. left trimmed                      : 0
#           no. right trimmed                     : 0
#           no. left and right trimmed            : 0
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. multiallelic normalized        : 0
#
#        total no. variants normalized            : 462
#        total no. variants observed              : 27311
#        total no. reference observed             : 0
#
# Time elapsed: 0.44s
#
# This is snippy-core 4.6.0
# Obtained from http://github.com/tseemann/snippy
# Enabling bundled tools for linux
# Found any2fasta - /usr/local/bin/any2fasta
# Found samtools - /usr/local/bin/samtools
# Found minimap2 - /usr/local/bin/minimap2
# Found bedtools - /usr/local/bin/bedtools
# Found snp-sites - /usr/local/bin/snp-sites
# Saving reference FASTA: core.ref.fa
# This is any2fasta 0.4.2
# Opening '/home/jupyter-mdprieto/tutorials/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Detected FASTA format
# Read 78307 lines from '/home/jupyter-mdprieto/tutorials/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Wrote 1 sequences from FASTA file.
# Processed 1 files.
# Done.
# Loaded 1 sequences totalling 6264404 bp.
# Will mask 0 regions totalling 0 bp ~ 0.00%
# 0	ERR10479510	snp=29320	del=604	ins=821	het=716	unaligned=305610
# 1	ERR10479511	snp=29300	del=642	ins=792	het=726	unaligned=309538
# 2	ERR10479512	snp=29314	del=626	ins=792	het=711	unaligned=305996
# 3	ERR10479513	snp=29345	del=627	ins=791	het=709	unaligned=305480
# 4	ERR10479514	snp=29328	del=668	ins=794	het=694	unaligned=306415
# 5	ERR10479515	snp=29315	del=603	ins=762	het=709	unaligned=306177
# 6	ERR10479516	snp=29293	del=622	ins=792	het=775	unaligned=305541
# 7	ERR10479517	snp=29336	del=637	ins=792	het=726	unaligned=305577
# 8	ERR10479518	snp=29321	del=607	ins=777	het=742	unaligned=305529
# 9	ERR10479519	snp=29311	del=664	ins=774	het=725	unaligned=306694
# Opening: core.tab
# Opening: core.vcf
# Processing contig: NC_002516.2
# Generating core.full.aln
# Creating TSV file: core.txt
# Running: snp-sites -c -o core.aln core.full.aln
# Have a suggestion? Tell me at http://github.com/tseemann/snippy/issues
# Done.
# Processing ERR10479511
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [samclip] samclip 0.4.0 by Torsten Seemann (@torstenseemann)
# [samclip] Loading: reference/ref.fa.fai
# [samclip] Found 1 sequences in reference/ref.fa.fai
# [M::process] read 320000 sequences (80000000 bp)...
# [M::process] read 253688 sequences (63394572 bp)...
# [M::mem_process_seqs] Processed 320000 reads in 35.774 CPU sec, 4.449 real sec
# [samclip] Processed 100000 records...
# [samclip] Processed 200000 records...
# [samclip] Processed 300000 records...
# [M::mem_process_seqs] Processed 253688 reads in 32.539 CPU sec, 3.972 real sec
# [samclip] Processed 400000 records...
# [samclip] Processed 500000 records...
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa mem -Y -M -R @RG\tID:ERR10479511\tSM:ERR10479511 -t 8 reference/ref.fa fake_reads.fq
# [main] Real time: 10.642 sec; CPU: 69.881 sec
# [samclip] Total SAM records 574979, removed 9845, allowed 1597, passed 565134
# [samclip] Header contained 3 lines
# [samclip] Done.
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# normalize v0.5
#
# options:     input VCF file                                  -
#          [o] output VCF file                                 -
#          [w] sorting window size                             10000
#          [n] no fail on reference inconsistency for non SNPs false
#          [q] quiet                                           false
#          [d] debug                                           false
#          [r] reference FASTA file                            reference/ref.fa
#
#
# stats: biallelic
#           no. left trimmed                      : 58
#           no. right trimmed                     : 390
#           no. left and right trimmed            : 18
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. biallelic normalized           : 466
#
#        multiallelic
#           no. left trimmed                      : 0
#           no. right trimmed                     : 0
#           no. left and right trimmed            : 0
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. multiallelic normalized        : 0
#
#        total no. variants normalized            : 466
#        total no. variants observed              : 27283
#        total no. reference observed             : 0
#
# Time elapsed: 0.44s
#
# This is snippy-core 4.6.0
# Obtained from http://github.com/tseemann/snippy
# Enabling bundled tools for linux
# Found any2fasta - /usr/local/bin/any2fasta
# Found samtools - /usr/local/bin/samtools
# Found minimap2 - /usr/local/bin/minimap2
# Found bedtools - /usr/local/bin/bedtools
# Found snp-sites - /usr/local/bin/snp-sites
# Saving reference FASTA: core.ref.fa
# This is any2fasta 0.4.2
# Opening '/home/jupyter-mdprieto/tutorials/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Detected FASTA format
# Read 78307 lines from '/home/jupyter-mdprieto/tutorials/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Wrote 1 sequences from FASTA file.
# Processed 1 files.
# Done.
# Loaded 1 sequences totalling 6264404 bp.
# Will mask 0 regions totalling 0 bp ~ 0.00%
# 0	ERR10479510	snp=29320	del=604	ins=821	het=716	unaligned=305610
# 1	ERR10479511	snp=29300	del=642	ins=792	het=726	unaligned=309538
# 2	ERR10479512	snp=29314	del=626	ins=792	het=711	unaligned=305996
# 3	ERR10479513	snp=29345	del=627	ins=791	het=709	unaligned=305480
# 4	ERR10479514	snp=29328	del=668	ins=794	het=694	unaligned=306415
# 5	ERR10479515	snp=29315	del=603	ins=762	het=709	unaligned=306177
# 6	ERR10479516	snp=29293	del=622	ins=792	het=775	unaligned=305541
# 7	ERR10479517	snp=29336	del=637	ins=792	het=726	unaligned=305577
# 8	ERR10479518	snp=29321	del=607	ins=777	het=742	unaligned=305529
# 9	ERR10479519	snp=29311	del=664	ins=774	het=725	unaligned=306694
# Opening: core.tab
# Opening: core.vcf
# Processing contig: NC_002516.2
# Generating core.full.aln
# Creating TSV file: core.txt
# Running: snp-sites -c -o core.aln core.full.aln
# This analysis is totally hard-core!
# Done.
# Processing ERR10479512
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [samclip] samclip 0.4.0 by Torsten Seemann (@torstenseemann)
# [samclip] Loading: reference/ref.fa.fai
# [samclip] Found 1 sequences in reference/ref.fa.fai
# [M::process] read 320000 sequences (80000000 bp)...
# [M::process] read 253030 sequences (63239792 bp)...
# [M::mem_process_seqs] Processed 320000 reads in 32.953 CPU sec, 4.038 real sec
# [samclip] Processed 100000 records...
# [samclip] Processed 200000 records...
# [samclip] Processed 300000 records...
# [M::mem_process_seqs] Processed 253030 reads in 29.130 CPU sec, 3.570 real sec
# [samclip] Processed 400000 records...
# [samclip] Processed 500000 records...
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa mem -Y -M -R @RG\tID:ERR10479512\tSM:ERR10479512 -t 8 reference/ref.fa fake_reads.fq[samclip] Total SAM records 574186, removed 9514, allowed 1594, passed 564672
#
# [main] Real time: 9.513 sec; CPU: 63.433 sec
# [samclip] Header contained 3 lines
# [samclip] Done.
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# normalize v0.5
#
# options:     input VCF file                                  -
#          [o] output VCF file                                 -
#          [w] sorting window size                             10000
#          [n] no fail on reference inconsistency for non SNPs false
#          [q] quiet                                           false
#          [d] debug                                           false
#          [r] reference FASTA file                            reference/ref.fa
#
#
# stats: biallelic
#           no. left trimmed                      : 59
#           no. right trimmed                     : 386
#           no. left and right trimmed            : 19
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. biallelic normalized           : 464
#
#        multiallelic
#           no. left trimmed                      : 0
#           no. right trimmed                     : 0
#           no. left and right trimmed            : 0
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. multiallelic normalized        : 0
#
#        total no. variants normalized            : 464
#        total no. variants observed              : 27298
#        total no. reference observed             : 0
#
# Time elapsed: 0.43s
#
# This is snippy-core 4.6.0
# Obtained from http://github.com/tseemann/snippy
# Enabling bundled tools for linux
# Found any2fasta - /usr/local/bin/any2fasta
# Found samtools - /usr/local/bin/samtools
# Found minimap2 - /usr/local/bin/minimap2
# Found bedtools - /usr/local/bin/bedtools
# Found snp-sites - /usr/local/bin/snp-sites
# Saving reference FASTA: core.ref.fa
# This is any2fasta 0.4.2
# Opening '/home/jupyter-mdprieto/tutorials/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Detected FASTA format
# Read 78307 lines from '/home/jupyter-mdprieto/tutorials/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Wrote 1 sequences from FASTA file.
# Processed 1 files.
# Done.
# Loaded 1 sequences totalling 6264404 bp.
# Will mask 0 regions totalling 0 bp ~ 0.00%
# 0	ERR10479510	snp=29320	del=604	ins=821	het=716	unaligned=305610
# 1	ERR10479511	snp=29300	del=642	ins=792	het=726	unaligned=309538
# 2	ERR10479512	snp=29314	del=626	ins=792	het=711	unaligned=305996
# 3	ERR10479513	snp=29345	del=627	ins=791	het=709	unaligned=305480
# 4	ERR10479514	snp=29328	del=668	ins=794	het=694	unaligned=306415
# 5	ERR10479515	snp=29315	del=603	ins=762	het=709	unaligned=306177
# 6	ERR10479516	snp=29293	del=622	ins=792	het=775	unaligned=305541
# 7	ERR10479517	snp=29336	del=637	ins=792	het=726	unaligned=305577
# 8	ERR10479518	snp=29321	del=607	ins=777	het=742	unaligned=305529
# 9	ERR10479519	snp=29311	del=664	ins=774	het=725	unaligned=306694
# Opening: core.tab
# Opening: core.vcf
# Processing contig: NC_002516.2
# Generating core.full.aln
# Creating TSV file: core.txt
# Running: snp-sites -c -o core.aln core.full.aln
# This analysis is totally hard-core!
# Done.
# Processing ERR10479513
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [samclip] samclip 0.4.0 by Torsten Seemann (@torstenseemann)
# [samclip] Loading: reference/ref.fa.fai
# [samclip] Found 1 sequences in reference/ref.fa.fai
# [M::process] read 320000 sequences (80000000 bp)...
# [M::process] read 252942 sequences (63206218 bp)...
# [M::mem_process_seqs] Processed 320000 reads in 35.229 CPU sec, 4.380 real sec
# [samclip] Processed 100000 records...
# [samclip] Processed 200000 records...
# [samclip] Processed 300000 records...
# [M::mem_process_seqs] Processed 252942 reads in 30.148 CPU sec, 3.675 real sec
# [samclip] Processed 400000 records...
# [samclip] Processed 500000 records...
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa mem[samclip] Total SAM records 574178, removed 9556, allowed 1657, passed 564622
#  -Y[samclip] Header contained 3 lines
#  -M[samclip] Done.
#  -R @RG\tID:ERR10479513\tSM:ERR10479513 -t 8 reference/ref.fa fake_reads.fq
# [main] Real time: 9.989 sec; CPU: 66.700 sec
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# normalize v0.5
#
# options:     input VCF file                                  -
#          [o] output VCF file                                 -
#          [w] sorting window size                             10000
#          [n] no fail on reference inconsistency for non SNPs false
#          [q] quiet                                           false
#          [d] debug                                           false
#          [r] reference FASTA file                            reference/ref.fa
#
#
# stats: biallelic
#           no. left trimmed                      : 58
#           no. right trimmed                     : 387
#           no. left and right trimmed            : 19
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. biallelic normalized           : 464
#
#        multiallelic
#           no. left trimmed                      : 0
#           no. right trimmed                     : 0
#           no. left and right trimmed            : 0
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. multiallelic normalized        : 0
#
#        total no. variants normalized            : 464
#        total no. variants observed              : 27315
#        total no. reference observed             : 0
#
# Time elapsed: 0.45s
#
# This is snippy-core 4.6.0
# Obtained from http://github.com/tseemann/snippy
# Enabling bundled tools for linux
# Found any2fasta - /usr/local/bin/any2fasta
# Found samtools - /usr/local/bin/samtools
# Found minimap2 - /usr/local/bin/minimap2
# Found bedtools - /usr/local/bin/bedtools
# Found snp-sites - /usr/local/bin/snp-sites
# Saving reference FASTA: core.ref.fa
# This is any2fasta 0.4.2
# Opening '/home/jupyter-mdprieto/tutorials/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Detected FASTA format
# Read 78307 lines from '/home/jupyter-mdprieto/tutorials/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Wrote 1 sequences from FASTA file.
# Processed 1 files.
# Done.
# Loaded 1 sequences totalling 6264404 bp.
# Will mask 0 regions totalling 0 bp ~ 0.00%
# 0	ERR10479510	snp=29320	del=604	ins=821	het=716	unaligned=305610
# 1	ERR10479511	snp=29300	del=642	ins=792	het=726	unaligned=309538
# 2	ERR10479512	snp=29314	del=626	ins=792	het=711	unaligned=305996
# 3	ERR10479513	snp=29345	del=627	ins=791	het=709	unaligned=305480
# 4	ERR10479514	snp=29328	del=668	ins=794	het=694	unaligned=306415
# 5	ERR10479515	snp=29315	del=603	ins=762	het=709	unaligned=306177
# 6	ERR10479516	snp=29293	del=622	ins=792	het=775	unaligned=305541
# 7	ERR10479517	snp=29336	del=637	ins=792	het=726	unaligned=305577
# 8	ERR10479518	snp=29321	del=607	ins=777	het=742	unaligned=305529
# 9	ERR10479519	snp=29311	del=664	ins=774	het=725	unaligned=306694
# Opening: core.tab
# Opening: core.vcf
# Processing contig: NC_002516.2
# Generating core.full.aln
# Creating TSV file: core.txt
# Running: snp-sites -c -o core.aln core.full.aln
# Run 'snp-sites -b -c -o phylo.aln core.full.aln' for IQTree, BEAST, RaxML
# Done.
# Processing ERR10479514
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [samclip] samclip 0.4.0 by Torsten Seemann (@torstenseemann)
# [samclip] Loading: reference/ref.fa.fai
# [samclip] Found 1 sequences in reference/ref.fa.fai
# [M::process] read 320000 sequences (80000000 bp)...
# [M::process] read 253342 sequences (63309110 bp)...
# [M::mem_process_seqs] Processed 320000 reads in 34.261 CPU sec, 4.228 real sec
# [samclip] Processed 100000 records...
# [samclip] Processed 200000 records...
# [samclip] Processed 300000 records...
# [M::mem_process_seqs] Processed 253342 reads in 31.339 CPU sec, 3.838 real sec
# [samclip] Processed 400000 records...
# [samclip] Processed 500000 records...
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa mem -Y -M -R @RG\tID:ERR10479514\tSM:ERR10479514 -t 8 reference/ref.fa fake_reads.fq[samclip] Total SAM records 574536, removed 9650, allowed 1603, passed 564886
# [samclip] Header contained 3 lines
# [samclip] Done.
#
# [main] Real time: 10.293 sec; CPU: 67.166 sec
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# normalize v0.5
#
# options:     input VCF file                                  -
#          [o] output VCF file                                 -
#          [w] sorting window size                             10000
#          [n] no fail on reference inconsistency for non SNPs false
#          [q] quiet                                           false
#          [d] debug                                           false
#          [r] reference FASTA file                            reference/ref.fa
#
#
# stats: biallelic
#           no. left trimmed                      : 61
#           no. right trimmed                     : 393
#           no. left and right trimmed            : 18
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. biallelic normalized           : 472
#
#        multiallelic
#           no. left trimmed                      : 0
#           no. right trimmed                     : 0
#           no. left and right trimmed            : 0
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. multiallelic normalized        : 0
#
#        total no. variants normalized            : 472
#        total no. variants observed              : 27309
#        total no. reference observed             : 0
#
# Time elapsed: 0.45s
#
# This is snippy-core 4.6.0
# Obtained from http://github.com/tseemann/snippy
# Enabling bundled tools for linux
# Found any2fasta - /usr/local/bin/any2fasta
# Found samtools - /usr/local/bin/samtools
# Found minimap2 - /usr/local/bin/minimap2
# Found bedtools - /usr/local/bin/bedtools
# Found snp-sites - /usr/local/bin/snp-sites
# Saving reference FASTA: core.ref.fa
# This is any2fasta 0.4.2
# Opening '/home/jupyter-mdprieto/tutorials/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Detected FASTA format
# Read 78307 lines from '/home/jupyter-mdprieto/tutorials/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Wrote 1 sequences from FASTA file.
# Processed 1 files.
# Done.
# Loaded 1 sequences totalling 6264404 bp.
# Will mask 0 regions totalling 0 bp ~ 0.00%
# 0	ERR10479510	snp=29320	del=604	ins=821	het=716	unaligned=305610
# 1	ERR10479511	snp=29300	del=642	ins=792	het=726	unaligned=309538
# 2	ERR10479512	snp=29314	del=626	ins=792	het=711	unaligned=305996
# 3	ERR10479513	snp=29345	del=627	ins=791	het=709	unaligned=305480
# 4	ERR10479514	snp=29328	del=668	ins=794	het=694	unaligned=306415
# 5	ERR10479515	snp=29315	del=603	ins=762	het=709	unaligned=306177
# 6	ERR10479516	snp=29293	del=622	ins=792	het=775	unaligned=305541
# 7	ERR10479517	snp=29336	del=637	ins=792	het=726	unaligned=305577
# 8	ERR10479518	snp=29321	del=607	ins=777	het=742	unaligned=305529
# 9	ERR10479519	snp=29311	del=664	ins=774	het=725	unaligned=306694
# Opening: core.tab
# Opening: core.vcf
# Processing contig: NC_002516.2
# Generating core.full.aln
# Creating TSV file: core.txt
# Running: snp-sites -c -o core.aln core.full.aln
# Found a bug? Post it at http://github.com/tseemann/snippy/issues
# Done.
# Processing ERR10479515
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [samclip] samclip 0.4.0 by Torsten Seemann (@torstenseemann)
# [samclip] Loading: reference/ref.fa.fai
# [samclip] Found 1 sequences in reference/ref.fa.fai
# [M::process] read 320000 sequences (80000000 bp)...
# [M::process] read 252588 sequences (63122680 bp)...
# [M::mem_process_seqs] Processed 320000 reads in 33.818 CPU sec, 4.177 real sec
# [samclip] Processed 100000 records...
# [samclip] Processed 200000 records...
# [samclip] Processed 300000 records...
# [M::mem_process_seqs] Processed 252588 reads in 29.570 CPU sec, 3.620 real sec
# [samclip] Processed 400000 records...
# [samclip] Processed 500000 records...
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa mem -Y -M -R @RG\tID:ERR10479515\tSM:ERR10479515 -t 8 reference/ref.fa fake_reads.fq
# [main] Real time: 9.828 sec; CPU: 64.985 sec
# [samclip] Total SAM records 573763, removed 9498, allowed 1571, passed 564265
# [samclip] Header contained 3 lines
# [samclip] Done.
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# normalize v0.5
#
# options:     input VCF file                                  -
#          [o] output VCF file                                 -
#          [w] sorting window size                             10000
#          [n] no fail on reference inconsistency for non SNPs false
#          [q] quiet                                           false
#          [d] debug                                           false
#          [r] reference FASTA file                            reference/ref.fa
#
#
# stats: biallelic
#           no. left trimmed                      : 57
#           no. right trimmed                     : 387
#           no. left and right trimmed            : 15
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. biallelic normalized           : 459
#
#        multiallelic
#           no. left trimmed                      : 0
#           no. right trimmed                     : 0
#           no. left and right trimmed            : 0
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. multiallelic normalized        : 0
#
#        total no. variants normalized            : 459
#        total no. variants observed              : 27299
#        total no. reference observed             : 0
#
# Time elapsed: 0.44s
#
# This is snippy-core 4.6.0
# Obtained from http://github.com/tseemann/snippy
# Enabling bundled tools for linux
# Found any2fasta - /usr/local/bin/any2fasta
# Found samtools - /usr/local/bin/samtools
# Found minimap2 - /usr/local/bin/minimap2
# Found bedtools - /usr/local/bin/bedtools
# Found snp-sites - /usr/local/bin/snp-sites
# Saving reference FASTA: core.ref.fa
# This is any2fasta 0.4.2
# Opening '/home/jupyter-mdprieto/tutorials/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Detected FASTA format
# Read 78307 lines from '/home/jupyter-mdprieto/tutorials/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Wrote 1 sequences from FASTA file.
# Processed 1 files.
# Done.
# Loaded 1 sequences totalling 6264404 bp.
# Will mask 0 regions totalling 0 bp ~ 0.00%
# 0	ERR10479510	snp=29320	del=604	ins=821	het=716	unaligned=305610
# 1	ERR10479511	snp=29300	del=642	ins=792	het=726	unaligned=309538
# 2	ERR10479512	snp=29314	del=626	ins=792	het=711	unaligned=305996
# 3	ERR10479513	snp=29345	del=627	ins=791	het=709	unaligned=305480
# 4	ERR10479514	snp=29328	del=668	ins=794	het=694	unaligned=306415
# 5	ERR10479515	snp=29315	del=603	ins=762	het=709	unaligned=306177
# 6	ERR10479516	snp=29293	del=622	ins=792	het=775	unaligned=305541
# 7	ERR10479517	snp=29336	del=637	ins=792	het=726	unaligned=305577
# 8	ERR10479518	snp=29321	del=607	ins=777	het=742	unaligned=305529
# 9	ERR10479519	snp=29311	del=664	ins=774	het=725	unaligned=306694
# Opening: core.tab
# Opening: core.vcf
# Processing contig: NC_002516.2
# Generating core.full.aln
# Creating TSV file: core.txt
# Running: snp-sites -c -o core.aln core.full.aln
# Have a suggestion? Tell me at http://github.com/tseemann/snippy/issues
# Done.
# Processing ERR10479516
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [samclip] samclip 0.4.0 by Torsten Seemann (@torstenseemann)
# [samclip] Loading: reference/ref.fa.fai
# [samclip] Found 1 sequences in reference/ref.fa.fai
# [M::process] read 320000 sequences (80000000 bp)...
# [M::process] read 252052 sequences (62942802 bp)...
# [M::mem_process_seqs] Processed 320000 reads in 34.261 CPU sec, 4.228 real sec
# [samclip] Processed 100000 records...
# [samclip] Processed 200000 records...
# [samclip] Processed 300000 records...
# [M::mem_process_seqs] Processed 252052 reads in 29.218 CPU sec, 3.572 real sec
# [samclip] Processed 400000 records...
# [samclip] Processed 500000 records...
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa mem -Y -M -R @RG\tID:ERR10479516\tSM:ERR10479516[samclip] Total SAM records 573365, removed 9565, allowed 1648, passed 563800
#  -t[samclip] Header contained 3 lines
#  8[samclip] Done.
#  reference/ref.fa fake_reads.fq
# [main] Real time: 9.759 sec; CPU: 64.756 sec
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# normalize v0.5
#
# options:     input VCF file                                  -
#          [o] output VCF file                                 -
#          [w] sorting window size                             10000
#          [n] no fail on reference inconsistency for non SNPs false
#          [q] quiet                                           false
#          [d] debug                                           false
#          [r] reference FASTA file                            reference/ref.fa
#
#
# stats: biallelic
#           no. left trimmed                      : 55
#           no. right trimmed                     : 386
#           no. left and right trimmed            : 18
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. biallelic normalized           : 459
#
#        multiallelic
#           no. left trimmed                      : 0
#           no. right trimmed                     : 0
#           no. left and right trimmed            : 0
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. multiallelic normalized        : 0
#
#        total no. variants normalized            : 459
#        total no. variants observed              : 27283
#        total no. reference observed             : 0
#
# Time elapsed: 0.46s
#
# This is snippy-core 4.6.0
# Obtained from http://github.com/tseemann/snippy
# Enabling bundled tools for linux
# Found any2fasta - /usr/local/bin/any2fasta
# Found samtools - /usr/local/bin/samtools
# Found minimap2 - /usr/local/bin/minimap2
# Found bedtools - /usr/local/bin/bedtools
# Found snp-sites - /usr/local/bin/snp-sites
# Saving reference FASTA: core.ref.fa
# This is any2fasta 0.4.2
# Opening '/home/jupyter-mdprieto/tutorials/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Detected FASTA format
# Read 78307 lines from '/home/jupyter-mdprieto/tutorials/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Wrote 1 sequences from FASTA file.
# Processed 1 files.
# Done.
# Loaded 1 sequences totalling 6264404 bp.
# Will mask 0 regions totalling 0 bp ~ 0.00%
# 0	ERR10479510	snp=29320	del=604	ins=821	het=716	unaligned=305610
# 1	ERR10479511	snp=29300	del=642	ins=792	het=726	unaligned=309538
# 2	ERR10479512	snp=29314	del=626	ins=792	het=711	unaligned=305996
# 3	ERR10479513	snp=29345	del=627	ins=791	het=709	unaligned=305480
# 4	ERR10479514	snp=29328	del=668	ins=794	het=694	unaligned=306415
# 5	ERR10479515	snp=29315	del=603	ins=762	het=709	unaligned=306177
# 6	ERR10479516	snp=29293	del=622	ins=792	het=775	unaligned=305541
# 7	ERR10479517	snp=29336	del=637	ins=792	het=726	unaligned=305577
# 8	ERR10479518	snp=29321	del=607	ins=777	het=742	unaligned=305529
# 9	ERR10479519	snp=29311	del=664	ins=774	het=725	unaligned=306694
# Opening: core.tab
# Opening: core.vcf
# Processing contig: NC_002516.2
# Generating core.full.aln
# Creating TSV file: core.txt
# Running: snp-sites -c -o core.aln core.full.aln
# This analysis is totally hard-core!
# Done.
# Processing ERR10479517
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [samclip] samclip 0.4.0 by Torsten Seemann (@torstenseemann)
# [samclip] Loading: reference/ref.fa.fai
# [samclip] Found 1 sequences in reference/ref.fa.fai
# [M::process] read 320000 sequences (80000000 bp)...
# [M::process] read 252422 sequences (63033870 bp)...
# [M::mem_process_seqs] Processed 320000 reads in 34.616 CPU sec, 4.299 real sec
# [samclip] Processed 100000 records...
# [samclip] Processed 200000 records...
# [samclip] Processed 300000 records...
# [M::mem_process_seqs] Processed 252422 reads in 29.203 CPU sec, 3.554 real sec
# [samclip] Processed 400000 records...
# [samclip] Processed 500000 records...
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa mem -Y -M -R @RG\tID:ERR10479517\tSM:ERR10479517 -t 8 reference/ref.fa fake_reads.fq
# [main] Real time: 9.862 sec; CPU: 65.210 sec
# [samclip] Total SAM records 573735, removed 9500, allowed 1661, passed 564235
# [samclip] Header contained 3 lines
# [samclip] Done.
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# normalize v0.5
#
# options:     input VCF file                                  -
#          [o] output VCF file                                 -
#          [w] sorting window size                             10000
#          [n] no fail on reference inconsistency for non SNPs false
#          [q] quiet                                           false
#          [d] debug                                           false
#          [r] reference FASTA file                            reference/ref.fa
#
#
# stats: biallelic
#           no. left trimmed                      : 56
#           no. right trimmed                     : 386
#           no. left and right trimmed            : 18
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. biallelic normalized           : 460
#
#        multiallelic
#           no. left trimmed                      : 0
#           no. right trimmed                     : 0
#           no. left and right trimmed            : 0
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. multiallelic normalized        : 0
#
#        total no. variants normalized            : 460
#        total no. variants observed              : 27305
#        total no. reference observed             : 0
#
# Time elapsed: 0.44s
#
# This is snippy-core 4.6.0
# Obtained from http://github.com/tseemann/snippy
# Enabling bundled tools for linux
# Found any2fasta - /usr/local/bin/any2fasta
# Found samtools - /usr/local/bin/samtools
# Found minimap2 - /usr/local/bin/minimap2
# Found bedtools - /usr/local/bin/bedtools
# Found snp-sites - /usr/local/bin/snp-sites
# Saving reference FASTA: core.ref.fa
# This is any2fasta 0.4.2
# Opening '/home/jupyter-mdprieto/tutorials/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Detected FASTA format
# Read 78307 lines from '/home/jupyter-mdprieto/tutorials/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Wrote 1 sequences from FASTA file.
# Processed 1 files.
# Done.
# Loaded 1 sequences totalling 6264404 bp.
# Will mask 0 regions totalling 0 bp ~ 0.00%
# 0	ERR10479510	snp=29320	del=604	ins=821	het=716	unaligned=305610
# 1	ERR10479511	snp=29300	del=642	ins=792	het=726	unaligned=309538
# 2	ERR10479512	snp=29314	del=626	ins=792	het=711	unaligned=305996
# 3	ERR10479513	snp=29345	del=627	ins=791	het=709	unaligned=305480
# 4	ERR10479514	snp=29328	del=668	ins=794	het=694	unaligned=306415
# 5	ERR10479515	snp=29315	del=603	ins=762	het=709	unaligned=306177
# 6	ERR10479516	snp=29293	del=622	ins=792	het=775	unaligned=305541
# 7	ERR10479517	snp=29336	del=637	ins=792	het=726	unaligned=305577
# 8	ERR10479518	snp=29321	del=607	ins=777	het=742	unaligned=305529
# 9	ERR10479519	snp=29311	del=664	ins=774	het=725	unaligned=306694
# Opening: core.tab
# Opening: core.vcf
# Processing contig: NC_002516.2
# Generating core.full.aln
# Creating TSV file: core.txt
# Running: snp-sites -c -o core.aln core.full.aln
# Have a suggestion? Tell me at http://github.com/tseemann/snippy/issues
# Done.
# Processing ERR10479518
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [samclip] samclip 0.4.0 by Torsten Seemann (@torstenseemann)
# [samclip] Loading: reference/ref.fa.fai
# [samclip] Found 1 sequences in reference/ref.fa.fai
# [M::process] read 320000 sequences (80000000 bp)...
# [M::process] read 265630 sequences (66341968 bp)...
# [M::mem_process_seqs] Processed 320000 reads in 33.889 CPU sec, 4.160 real sec
# [samclip] Processed 100000 records...
# [samclip] Processed 200000 records...
# [samclip] Processed 300000 records...
# [M::mem_process_seqs] Processed 265630 reads in 33.201 CPU sec, 4.059 real sec
# [samclip] Processed 400000 records...
# [samclip] Processed 500000 records...
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa mem -Y -M -R @RG\tID:ERR10479518\tSM:ERR10479518 -t 8 reference/ref.fa fake_reads.fq[samclip] Total SAM records 586987, removed 9619, allowed 1635, passed 577368
#
# [main] Real time: 10.307 sec; CPU: 68.311 sec
# [samclip] Header contained 3 lines
# [samclip] Done.
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# normalize v0.5
#
# options:     input VCF file                                  -
#          [o] output VCF file                                 -
#          [w] sorting window size                             10000
#          [n] no fail on reference inconsistency for non SNPs false
#          [q] quiet                                           false
#          [d] debug                                           false
#          [r] reference FASTA file                            reference/ref.fa
#
#
# stats: biallelic
#           no. left trimmed                      : 57
#           no. right trimmed                     : 384
#           no. left and right trimmed            : 18
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. biallelic normalized           : 459
#
#        multiallelic
#           no. left trimmed                      : 0
#           no. right trimmed                     : 0
#           no. left and right trimmed            : 0
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. multiallelic normalized        : 0
#
#        total no. variants normalized            : 459
#        total no. variants observed              : 27292
#        total no. reference observed             : 0
#
# Time elapsed: 0.45s
#
# This is snippy-core 4.6.0
# Obtained from http://github.com/tseemann/snippy
# Enabling bundled tools for linux
# Found any2fasta - /usr/local/bin/any2fasta
# Found samtools - /usr/local/bin/samtools
# Found minimap2 - /usr/local/bin/minimap2
# Found bedtools - /usr/local/bin/bedtools
# Found snp-sites - /usr/local/bin/snp-sites
# Saving reference FASTA: core.ref.fa
# This is any2fasta 0.4.2
# Opening '/home/jupyter-mdprieto/tutorials/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Detected FASTA format
# Read 78307 lines from '/home/jupyter-mdprieto/tutorials/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Wrote 1 sequences from FASTA file.
# Processed 1 files.
# Done.
# Loaded 1 sequences totalling 6264404 bp.
# Will mask 0 regions totalling 0 bp ~ 0.00%
# 0	ERR10479510	snp=29320	del=604	ins=821	het=716	unaligned=305610
# 1	ERR10479511	snp=29300	del=642	ins=792	het=726	unaligned=309538
# 2	ERR10479512	snp=29314	del=626	ins=792	het=711	unaligned=305996
# 3	ERR10479513	snp=29345	del=627	ins=791	het=709	unaligned=305480
# 4	ERR10479514	snp=29328	del=668	ins=794	het=694	unaligned=306415
# 5	ERR10479515	snp=29315	del=603	ins=762	het=709	unaligned=306177
# 6	ERR10479516	snp=29293	del=622	ins=792	het=775	unaligned=305541
# 7	ERR10479517	snp=29336	del=637	ins=792	het=726	unaligned=305577
# 8	ERR10479518	snp=29321	del=607	ins=777	het=742	unaligned=305529
# 9	ERR10479519	snp=29311	del=664	ins=774	het=725	unaligned=306694
# Opening: core.tab
# Opening: core.vcf
# Processing contig: NC_002516.2
# Generating core.full.aln
# Creating TSV file: core.txt
# Running: snp-sites -c -o core.aln core.full.aln
# Found a bug? Post it at http://github.com/tseemann/snippy/issues
# Done.
# Processing ERR10479519
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [samclip] samclip 0.4.0 by Torsten Seemann (@torstenseemann)
# [samclip] Loading: reference/ref.fa.fai
# [samclip] Found 1 sequences in reference/ref.fa.fai
# [M::process] read 320000 sequences (80000000 bp)...
# [M::process] read 252874 sequences (63131650 bp)...
# [M::mem_process_seqs] Processed 320000 reads in 34.317 CPU sec, 4.217 real sec
# [samclip] Processed 100000 records...
# [samclip] Processed 200000 records...
# [samclip] Processed 300000 records...
# [M::mem_process_seqs] Processed 252874 reads in 29.586 CPU sec, 3.608 real sec
# [samclip] Processed 400000 records...
# [samclip] Processed 500000 records...
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa mem -Y -M -R @RG\tID:ERR10479519\tSM:ERR10479519 -t 8 reference/ref.fa fake_reads.fq
# [main] Real time: 9.864 sec; CPU: 65.236 sec
# [samclip] Total SAM records 574230, removed 9558, allowed 1557, passed 564672
# [samclip] Header contained 3 lines
# [samclip] Done.
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# normalize v0.5
#
# options:     input VCF file                                  -
#          [o] output VCF file                                 -
#          [w] sorting window size                             10000
#          [n] no fail on reference inconsistency for non SNPs false
#          [q] quiet                                           false
#          [d] debug                                           false
#          [r] reference FASTA file                            reference/ref.fa
#
#
# stats: biallelic
#           no. left trimmed                      : 56
#           no. right trimmed                     : 388
#           no. left and right trimmed            : 17
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. biallelic normalized           : 461
#
#        multiallelic
#           no. left trimmed                      : 0
#           no. right trimmed                     : 0
#           no. left and right trimmed            : 0
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. multiallelic normalized        : 0
#
#        total no. variants normalized            : 461
#        total no. variants observed              : 27292
#        total no. reference observed             : 0
#
# Time elapsed: 0.44s
#
# This is snippy-core 4.6.0
# Obtained from http://github.com/tseemann/snippy
# Enabling bundled tools for linux
# Found any2fasta - /usr/local/bin/any2fasta
# Found samtools - /usr/local/bin/samtools
# Found minimap2 - /usr/local/bin/minimap2
# Found bedtools - /usr/local/bin/bedtools
# Found snp-sites - /usr/local/bin/snp-sites
# Saving reference FASTA: core.ref.fa
# This is any2fasta 0.4.2
# Opening '/home/jupyter-mdprieto/tutorials/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Detected FASTA format
# Read 78307 lines from '/home/jupyter-mdprieto/tutorials/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Wrote 1 sequences from FASTA file.
# Processed 1 files.
# Done.
# Loaded 1 sequences totalling 6264404 bp.
# Will mask 0 regions totalling 0 bp ~ 0.00%
# 0	ERR10479510	snp=29320	del=604	ins=821	het=716	unaligned=305610
# 1	ERR10479511	snp=29300	del=642	ins=792	het=726	unaligned=309538
# 2	ERR10479512	snp=29314	del=626	ins=792	het=711	unaligned=305996
# 3	ERR10479513	snp=29345	del=627	ins=791	het=709	unaligned=305480
# 4	ERR10479514	snp=29328	del=668	ins=794	het=694	unaligned=306415
# 5	ERR10479515	snp=29315	del=603	ins=762	het=709	unaligned=306177
# 6	ERR10479516	snp=29293	del=622	ins=792	het=775	unaligned=305541
# 7	ERR10479517	snp=29336	del=637	ins=792	het=726	unaligned=305577
# 8	ERR10479518	snp=29321	del=607	ins=777	het=742	unaligned=305529
# 9	ERR10479519	snp=29311	del=664	ins=774	het=725	unaligned=306694
# Opening: core.tab
# Opening: core.vcf
# Processing contig: NC_002516.2
# Generating core.full.aln
# Creating TSV file: core.txt
# Running: snp-sites -c -o core.aln core.full.aln
# Found a bug? Post it at http://github.com/tseemann/snippy/issues
# Done.

# %% [markdown]
# Once we have the data from the previous command, we perform a few additional steps to clean our results and have them ready for phylogenetic analysis.
#
# 1. We run **snippy-core** to summarize the **SNVs** that are present only in genes contained in all isolates
#
# 2. Then, **Gubbins** eliminates the features that are transmitted through horizontal gene transfer.
#
# 3. Once we have the cleaned alignment, we use **snp-sites** to extract the sites in the alignment with a **SNV**

# %%
cd $HOME/tutorials/results/snippy

# clean file
singularity exec $SNIPPY_IMG snippy-clean_full_aln core.full.aln > clean.full.aln

# gubbins remove horizontal gene transfer 
singularity exec $GUBBINS_IMG run_gubbins.py -p gubbins clean.full.aln

# SNP-sites
singularity exec $SNIPPY_IMG snp-sites -c gubbins.filtered_polymorphic_sites.fasta > clean.core.aln
# Out:
# --- Gubbins 3.2.1 ---
#
# Croucher N. J., Page A. J., Connor T. R., Delaney A. J., Keane J. A., Bentley S. D., Parkhill J., Harris S.R. "Rapid phylogenetic analysis of large samples of recombinant bacterial whole genome sequences using Gubbins". Nucleic Acids Res. 2015 Feb 18;43(3):e15. doi: 10.1093/nar/gku1196.
#
# Checking dependencies and input files...
#
# Checking input alignment file...
#
# Filtering input alignment...
# ...done. Run time: 4.10 s
#
# Running Gubbins to detect SNPs...
# gubbins /home/jupyter-mdprieto/tutorials/results/snippy/tmpo8dgx1v6/clean.full.aln
# ...done. Run time: 5.59 s
#
# Entering the main loop.
#
# *** Iteration 1 ***
#
# Constructing the phylogenetic tree with raxmlHPC-AVX2...
# raxmlHPC-AVX2 -safe -m GTRGAMMA -f d -p 1 -s /home/jupyter-mdprieto/tutorials/results/snippy/clean.full.aln.phylip -n clean.full.iteration_1 > /dev/null 2>&1
# ...done. Run time: 6.42 s
#
# Reconstructing ancestral sequences with pyjar...
#
# Fitting substitution model to tree...
# raxmlHPC-AVX2 -safe -m GTRGAMMA -s clean.full.aln.snp_sites.aln -n clean.full.iteration_1_reconstruction -t /home/jupyter-mdprieto/tutorials/results/snippy/tmpo8dgx1v6/clean.full.iteration_1.tre.rooted -f e -w /home/jupyter-mdprieto/tutorials/results/snippy/tmpo8dgx1v6
# Warning, you specified a working directory via "-w"
# Keep in mind that RAxML only accepts absolute path names, not relative ones!
#
# RAxML can't, parse the alignment file as phylip file
# it will now try to parse it as FASTA file
#
#
#
# Using BFGS method to optimize GTR rate parameters, to disable this specify "--no-bfgs"
#
#
#
# This is RAxML version 8.2.12 released by Alexandros Stamatakis on May 2018.
#
# With greatly appreciated code contributions by:
# Andre Aberer      (HITS)
# Simon Berger      (HITS)
# Alexey Kozlov     (HITS)
# Kassian Kobert    (HITS)
# David Dao         (KIT and HITS)
# Sarah Lutteropp   (KIT and HITS)
# Nick Pattengale   (Sandia)
# Wayne Pfeiffer    (SDSC)
# Akifumi S. Tanabe (NRIFS)
# Charlie Taylor    (UF)
#
#
# Alignment has 346 distinct alignment patterns
#
# Proportion of gaps and completely undetermined characters in this alignment: 0.55%
#
# RAxML Model Optimization up to an accuracy of 0.100000 log likelihood units
#
# Using 1 distinct models/data partitions with joint branch length optimization
#
#
# All free model parameters will be estimated by RAxML
# GAMMA model of rate heterogeneity, ML estimate of alpha-parameter
#
# GAMMA Model parameters will be estimated up to an accuracy of 0.1000000000 Log Likelihood units
#
# Partition: 0
# Alignment Patterns: 346
# Name: No Name Provided
# DataType: DNA
# Substitution Matrix: GTR
#
#
#
#
# RAxML was called as follows:
#
# raxmlHPC-AVX2 -safe -m GTRGAMMA -s clean.full.aln.snp_sites.aln -n clean.full.iteration_1_reconstruction -t /home/jupyter-mdprieto/tutorials/results/snippy/tmpo8dgx1v6/clean.full.iteration_1.tre.rooted -f e -w /home/jupyter-mdprieto/tutorials/results/snippy/tmpo8dgx1v6
#
#
#
# WARNING the alpha parameter with a value of 16.449369 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 31.951557 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 66.669423 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 146.326613 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 321.051613 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 723.988756 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# Model parameters (binary file format) written to: /home/jupyter-mdprieto/tutorials/results/snippy/tmpo8dgx1v6/RAxML_binaryModelParameters.clean.full.iteration_1_reconstruction
# 0.300806 -78722.888899
#
#
# Overall Time for Tree Evaluation 0.300890
# Final GAMMA  likelihood: -78722.888899
#
# Number of free parameters for AIC-TEST(BR-LEN): 28
# Number of free parameters for AIC-TEST(NO-BR-LEN): 9
#
#
# Model Parameters of Partition 0, Name: No Name Provided, Type of Data: DNA
# alpha: 1000.000000
# Tree-Length: 3.527694
# rate A <-> C: 1.567754
# rate A <-> G: 104.277188
# rate A <-> T: 0.234031
# rate C <-> G: 17.619922
# rate C <-> T: 105.129187
# rate G <-> T: 1.000000
#
# freq pi(A): 0.241300
# freq pi(C): 0.259947
# freq pi(G): 0.275592
# freq pi(T): 0.223161
#
# Final tree written to:                 /home/jupyter-mdprieto/tutorials/results/snippy/tmpo8dgx1v6/RAxML_result.clean.full.iteration_1_reconstruction
# Execution Log File written to:         /home/jupyter-mdprieto/tutorials/results/snippy/tmpo8dgx1v6/RAxML_log.clean.full.iteration_1_reconstruction
#
# Running joint ancestral reconstruction with pyjar
#
# Transferring pyjar results onto original recombination-corrected tree
#
# Done transfer
# ...done. Run time: 8.50 s
#
# Running Gubbins to detect recombinations...
# gubbins -r -v clean.full.aln.gaps.vcf -a 100 -b 10000 -f /home/jupyter-mdprieto/tutorials/results/snippy/tmpo8dgx1v6/clean.full.aln -t clean.full.iteration_1.tre -m 3 -p 0.05 -i 1.0 /home/jupyter-mdprieto/tutorials/results/snippy/tmpo8dgx1v6/clean.full.iteration_1.internal.joint.aln
# ...done. Run time: 25.30 s
#
# Checking for convergence...
# ...done. Run time: 25.31 s
#
# *** Iteration 2 ***
#
# Constructing the phylogenetic tree with raxmlHPC-AVX2...
# raxmlHPC-AVX2 -safe -m GTRGAMMA -f d -p 1 -s /home/jupyter-mdprieto/tutorials/results/snippy/clean.full.iteration_1.tre.phylip -n clean.full.iteration_2 -t /home/jupyter-mdprieto/tutorials/results/snippy/clean.full.iteration_1.tre > /dev/null 2>&1
# ...done. Run time: 26.03 s
#
# Reconstructing ancestral sequences with pyjar...
#
# Fitting substitution model to tree...
# raxmlHPC-AVX2 -safe -m GTRGAMMA -s clean.full.aln.snp_sites.aln -n clean.full.iteration_2_reconstruction -t /home/jupyter-mdprieto/tutorials/results/snippy/tmpo8dgx1v6/clean.full.iteration_2.tre.rooted -f e -w /home/jupyter-mdprieto/tutorials/results/snippy/tmpo8dgx1v6
# Warning, you specified a working directory via "-w"
# Keep in mind that RAxML only accepts absolute path names, not relative ones!
#
# RAxML can't, parse the alignment file as phylip file
# it will now try to parse it as FASTA file
#
#
#
# Using BFGS method to optimize GTR rate parameters, to disable this specify "--no-bfgs"
#
#
#
# This is RAxML version 8.2.12 released by Alexandros Stamatakis on May 2018.
#
# With greatly appreciated code contributions by:
# Andre Aberer      (HITS)
# Simon Berger      (HITS)
# Alexey Kozlov     (HITS)
# Kassian Kobert    (HITS)
# David Dao         (KIT and HITS)
# Sarah Lutteropp   (KIT and HITS)
# Nick Pattengale   (Sandia)
# Wayne Pfeiffer    (SDSC)
# Akifumi S. Tanabe (NRIFS)
# Charlie Taylor    (UF)
#
#
# Alignment has 346 distinct alignment patterns
#
# Proportion of gaps and completely undetermined characters in this alignment: 0.55%
#
# RAxML Model Optimization up to an accuracy of 0.100000 log likelihood units
#
# Using 1 distinct models/data partitions with joint branch length optimization
#
#
# All free model parameters will be estimated by RAxML
# GAMMA model of rate heterogeneity, ML estimate of alpha-parameter
#
# GAMMA Model parameters will be estimated up to an accuracy of 0.1000000000 Log Likelihood units
#
# Partition: 0
# Alignment Patterns: 346
# Name: No Name Provided
# DataType: DNA
# Substitution Matrix: GTR
#
#
#
#
# RAxML was called as follows:
#
# raxmlHPC-AVX2 -safe -m GTRGAMMA -s clean.full.aln.snp_sites.aln -n clean.full.iteration_2_reconstruction -t /home/jupyter-mdprieto/tutorials/results/snippy/tmpo8dgx1v6/clean.full.iteration_2.tre.rooted -f e -w /home/jupyter-mdprieto/tutorials/results/snippy/tmpo8dgx1v6
#
#
#
# WARNING the alpha parameter with a value of 17.213383 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 32.171094 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 65.355908 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 141.299065 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 307.526032 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 690.872994 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# Model parameters (binary file format) written to: /home/jupyter-mdprieto/tutorials/results/snippy/tmpo8dgx1v6/RAxML_binaryModelParameters.clean.full.iteration_2_reconstruction
# 0.291496 -78848.196715
#
#
# Overall Time for Tree Evaluation 0.291604
# Final GAMMA  likelihood: -78848.196715
#
# Number of free parameters for AIC-TEST(BR-LEN): 28
# Number of free parameters for AIC-TEST(NO-BR-LEN): 9
#
#
# Model Parameters of Partition 0, Name: No Name Provided, Type of Data: DNA
# alpha: 1000.000000
# Tree-Length: 3.485946
# rate A <-> C: 0.970794
# rate A <-> G: 61.851263
# rate A <-> T: 0.177657
# rate C <-> G: 10.254324
# rate C <-> T: 62.776427
# rate G <-> T: 1.000000
#
# freq pi(A): 0.241300
# freq pi(C): 0.259947
# freq pi(G): 0.275592
# freq pi(T): 0.223161
#
# Final tree written to:                 /home/jupyter-mdprieto/tutorials/results/snippy/tmpo8dgx1v6/RAxML_result.clean.full.iteration_2_reconstruction
# Execution Log File written to:         /home/jupyter-mdprieto/tutorials/results/snippy/tmpo8dgx1v6/RAxML_log.clean.full.iteration_2_reconstruction
#
# Running joint ancestral reconstruction with pyjar
#
# Transferring pyjar results onto original recombination-corrected tree
#
# Done transfer
# ...done. Run time: 27.86 s
#
# Running Gubbins to detect recombinations...
# gubbins -r -v clean.full.aln.gaps.vcf -a 100 -b 10000 -f /home/jupyter-mdprieto/tutorials/results/snippy/tmpo8dgx1v6/clean.full.aln -t clean.full.iteration_2.tre -m 3 -p 0.05 -i 1.0 /home/jupyter-mdprieto/tutorials/results/snippy/tmpo8dgx1v6/clean.full.iteration_2.internal.joint.aln
# ...done. Run time: 44.85 s
#
# Checking for convergence...
# ...done. Run time: 44.85 s
#
# *** Iteration 3 ***
#
# Constructing the phylogenetic tree with raxmlHPC-AVX2...
# raxmlHPC-AVX2 -safe -m GTRGAMMA -f d -p 1 -s /home/jupyter-mdprieto/tutorials/results/snippy/clean.full.iteration_2.tre.phylip -n clean.full.iteration_3 -t /home/jupyter-mdprieto/tutorials/results/snippy/clean.full.iteration_2.tre > /dev/null 2>&1
# ...done. Run time: 45.68 s
#
# Reconstructing ancestral sequences with pyjar...
#
# Fitting substitution model to tree...
# raxmlHPC-AVX2 -safe -m GTRGAMMA -s clean.full.aln.snp_sites.aln -n clean.full.iteration_3_reconstruction -t /home/jupyter-mdprieto/tutorials/results/snippy/tmpo8dgx1v6/clean.full.iteration_3.tre.rooted -f e -w /home/jupyter-mdprieto/tutorials/results/snippy/tmpo8dgx1v6
# Warning, you specified a working directory via "-w"
# Keep in mind that RAxML only accepts absolute path names, not relative ones!
#
# RAxML can't, parse the alignment file as phylip file
# it will now try to parse it as FASTA file
#
#
#
# Using BFGS method to optimize GTR rate parameters, to disable this specify "--no-bfgs"
#
#
#
# This is RAxML version 8.2.12 released by Alexandros Stamatakis on May 2018.
#
# With greatly appreciated code contributions by:
# Andre Aberer      (HITS)
# Simon Berger      (HITS)
# Alexey Kozlov     (HITS)
# Kassian Kobert    (HITS)
# David Dao         (KIT and HITS)
# Sarah Lutteropp   (KIT and HITS)
# Nick Pattengale   (Sandia)
# Wayne Pfeiffer    (SDSC)
# Akifumi S. Tanabe (NRIFS)
# Charlie Taylor    (UF)
#
#
# Alignment has 346 distinct alignment patterns
#
# Proportion of gaps and completely undetermined characters in this alignment: 0.55%
#
# RAxML Model Optimization up to an accuracy of 0.100000 log likelihood units
#
# Using 1 distinct models/data partitions with joint branch length optimization
#
#
# All free model parameters will be estimated by RAxML
# GAMMA model of rate heterogeneity, ML estimate of alpha-parameter
#
# GAMMA Model parameters will be estimated up to an accuracy of 0.1000000000 Log Likelihood units
#
# Partition: 0
# Alignment Patterns: 346
# Name: No Name Provided
# DataType: DNA
# Substitution Matrix: GTR
#
#
#
#
# RAxML was called as follows:
#
# raxmlHPC-AVX2 -safe -m GTRGAMMA -s clean.full.aln.snp_sites.aln -n clean.full.iteration_3_reconstruction -t /home/jupyter-mdprieto/tutorials/results/snippy/tmpo8dgx1v6/clean.full.iteration_3.tre.rooted -f e -w /home/jupyter-mdprieto/tutorials/results/snippy/tmpo8dgx1v6
#
#
#
# WARNING the alpha parameter with a value of 17.213383 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 32.171094 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 65.355908 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 141.299065 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 307.526032 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 690.872994 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# Model parameters (binary file format) written to: /home/jupyter-mdprieto/tutorials/results/snippy/tmpo8dgx1v6/RAxML_binaryModelParameters.clean.full.iteration_3_reconstruction
# 0.292288 -78848.196715
#
#
# Overall Time for Tree Evaluation 0.292405
# Final GAMMA  likelihood: -78848.196715
#
# Number of free parameters for AIC-TEST(BR-LEN): 28
# Number of free parameters for AIC-TEST(NO-BR-LEN): 9
#
#
# Model Parameters of Partition 0, Name: No Name Provided, Type of Data: DNA
# alpha: 1000.000000
# Tree-Length: 3.485946
# rate A <-> C: 0.970794
# rate A <-> G: 61.851263
# rate A <-> T: 0.177657
# rate C <-> G: 10.254324
# rate C <-> T: 62.776427
# rate G <-> T: 1.000000
#
# freq pi(A): 0.241300
# freq pi(C): 0.259947
# freq pi(G): 0.275592
# freq pi(T): 0.223161
#
# Final tree written to:                 /home/jupyter-mdprieto/tutorials/results/snippy/tmpo8dgx1v6/RAxML_result.clean.full.iteration_3_reconstruction
# Execution Log File written to:         /home/jupyter-mdprieto/tutorials/results/snippy/tmpo8dgx1v6/RAxML_log.clean.full.iteration_3_reconstruction
#
# Running joint ancestral reconstruction with pyjar
#
# Transferring pyjar results onto original recombination-corrected tree
#
# Done transfer
# ...done. Run time: 47.52 s
#
# Running Gubbins to detect recombinations...
# gubbins -r -v clean.full.aln.gaps.vcf -a 100 -b 10000 -f /home/jupyter-mdprieto/tutorials/results/snippy/tmpo8dgx1v6/clean.full.aln -t clean.full.iteration_3.tre -m 3 -p 0.05 -i 1.0 /home/jupyter-mdprieto/tutorials/results/snippy/tmpo8dgx1v6/clean.full.iteration_3.internal.joint.aln
# ...done. Run time: 64.56 s
#
# Checking for convergence...
# ...done. Run time: 64.57 s
#
# *** Iteration 4 ***
#
# Constructing the phylogenetic tree with raxmlHPC-AVX2...
# raxmlHPC-AVX2 -safe -m GTRGAMMA -f d -p 1 -s /home/jupyter-mdprieto/tutorials/results/snippy/clean.full.iteration_3.tre.phylip -n clean.full.iteration_4 -t /home/jupyter-mdprieto/tutorials/results/snippy/clean.full.iteration_3.tre > /dev/null 2>&1
# ...done. Run time: 65.40 s
#
# Reconstructing ancestral sequences with pyjar...
#
# Fitting substitution model to tree...
# raxmlHPC-AVX2 -safe -m GTRGAMMA -s clean.full.aln.snp_sites.aln -n clean.full.iteration_4_reconstruction -t /home/jupyter-mdprieto/tutorials/results/snippy/tmpo8dgx1v6/clean.full.iteration_4.tre.rooted -f e -w /home/jupyter-mdprieto/tutorials/results/snippy/tmpo8dgx1v6
# Warning, you specified a working directory via "-w"
# Keep in mind that RAxML only accepts absolute path names, not relative ones!
#
# RAxML can't, parse the alignment file as phylip file
# it will now try to parse it as FASTA file
#
#
#
# Using BFGS method to optimize GTR rate parameters, to disable this specify "--no-bfgs"
#
#
#
# This is RAxML version 8.2.12 released by Alexandros Stamatakis on May 2018.
#
# With greatly appreciated code contributions by:
# Andre Aberer      (HITS)
# Simon Berger      (HITS)
# Alexey Kozlov     (HITS)
# Kassian Kobert    (HITS)
# David Dao         (KIT and HITS)
# Sarah Lutteropp   (KIT and HITS)
# Nick Pattengale   (Sandia)
# Wayne Pfeiffer    (SDSC)
# Akifumi S. Tanabe (NRIFS)
# Charlie Taylor    (UF)
#
#
# Alignment has 346 distinct alignment patterns
#
# Proportion of gaps and completely undetermined characters in this alignment: 0.55%
#
# RAxML Model Optimization up to an accuracy of 0.100000 log likelihood units
#
# Using 1 distinct models/data partitions with joint branch length optimization
#
#
# All free model parameters will be estimated by RAxML
# GAMMA model of rate heterogeneity, ML estimate of alpha-parameter
#
# GAMMA Model parameters will be estimated up to an accuracy of 0.1000000000 Log Likelihood units
#
# Partition: 0
# Alignment Patterns: 346
# Name: No Name Provided
# DataType: DNA
# Substitution Matrix: GTR
#
#
#
#
# RAxML was called as follows:
#
# raxmlHPC-AVX2 -safe -m GTRGAMMA -s clean.full.aln.snp_sites.aln -n clean.full.iteration_4_reconstruction -t /home/jupyter-mdprieto/tutorials/results/snippy/tmpo8dgx1v6/clean.full.iteration_4.tre.rooted -f e -w /home/jupyter-mdprieto/tutorials/results/snippy/tmpo8dgx1v6
#
#
#
# WARNING the alpha parameter with a value of 17.213383 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 32.171094 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 65.355908 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 141.299065 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 307.526032 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 690.872994 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# WARNING the alpha parameter with a value of 1000.000000 estimated by RAxML for partition number 0 with the name "No Name Provided"
# is larger than 10.000000. You should do a model test and confirm that you actually need to incorporate a model of rate heterogeneity!
# You can run inferences with a plain substitution model (without rate heterogeneity) by specifyng the CAT model and the "-V" option!
#
#
# Model parameters (binary file format) written to: /home/jupyter-mdprieto/tutorials/results/snippy/tmpo8dgx1v6/RAxML_binaryModelParameters.clean.full.iteration_4_reconstruction
# 0.291586 -78848.196715
#
#
# Overall Time for Tree Evaluation 0.291664
# Final GAMMA  likelihood: -78848.196715
#
# Number of free parameters for AIC-TEST(BR-LEN): 28
# Number of free parameters for AIC-TEST(NO-BR-LEN): 9
#
#
# Model Parameters of Partition 0, Name: No Name Provided, Type of Data: DNA
# alpha: 1000.000000
# Tree-Length: 3.485946
# rate A <-> C: 0.970794
# rate A <-> G: 61.851263
# rate A <-> T: 0.177657
# rate C <-> G: 10.254324
# rate C <-> T: 62.776427
# rate G <-> T: 1.000000
#
# freq pi(A): 0.241300
# freq pi(C): 0.259947
# freq pi(G): 0.275592
# freq pi(T): 0.223161
#
# Final tree written to:                 /home/jupyter-mdprieto/tutorials/results/snippy/tmpo8dgx1v6/RAxML_result.clean.full.iteration_4_reconstruction
# Execution Log File written to:         /home/jupyter-mdprieto/tutorials/results/snippy/tmpo8dgx1v6/RAxML_log.clean.full.iteration_4_reconstruction
#
# Running joint ancestral reconstruction with pyjar
#
# Transferring pyjar results onto original recombination-corrected tree
#
# Done transfer
# ...done. Run time: 67.27 s
#
# Running Gubbins to detect recombinations...
# gubbins -r -v clean.full.aln.gaps.vcf -a 100 -b 10000 -f /home/jupyter-mdprieto/tutorials/results/snippy/tmpo8dgx1v6/clean.full.aln -t clean.full.iteration_4.tre -m 3 -p 0.05 -i 1.0 /home/jupyter-mdprieto/tutorials/results/snippy/tmpo8dgx1v6/clean.full.iteration_4.internal.joint.aln
# ...done. Run time: 84.21 s
#
# Checking for convergence...
# Convergence after 4 iterations: Tree observed before.
#
# Exiting the main loop.
#
# Creating the final output...
# ...finished. Total run time: 84.25 s

# %% [markdown]
# Once we have conducted all of the above steps. We have a file that contains the **SNVs** present in genes common to all isolates (core-genes) and that were not obtained by horizontal gene transfer.
#
# This file can be used to create a phylogenetic tree.

# %%
# produce tree
$HOME/tutorials/tools/FastTree -gtr -nt clean.core.aln > clean.core.tree
# Out:
# FastTree Version 2.1.11 SSE3
# Alignment: clean.core.aln
# Nucleotide distances: Jukes-Cantor Joins: balanced Support: SH-like 1000
# Search: Normal +NNI +SPR (2 rounds range 10) +ML-NNI opt-each=1
# TopHits: 1.00*sqrtN close=default refresh=0.80
# ML Model: Generalized Time-Reversible, CAT approximation with 20 rate categories
# Initial topology in 0.05 seconds
# Refining topology: 14 rounds ME-NNIs, 2 rounds ME-SPRs, 7 rounds ML-NNIs
# Total branch-length 3.002 after 0.72 sec, 1 of 9 splits
# ML-NNI round 1: LogLk = -72517.017 NNIs 1 max delta 3.17 Time 1.28
# GTR Frequencies: 0.2436 0.2580 0.2725 0.2259ep 12 of 12
# GTR rates(ac ag at cg ct gt) 1.1798 14.4592 0.8504 0.7559 53.9537 1.0000
# Switched to using 20 rate categories (CAT approximation)15 of 20
# Rate categories were divided by 0.677 so that average rate = 1.0
# CAT-based log-likelihoods may not be comparable across runs
# Use -gamma for approximate but comparable Gamma(20) log-likelihoods
# ML-NNI round 2: LogLk = -67208.532 NNIs 1 max delta 0.00 Time 5.51
# Turning off heuristics for final round of ML NNIs (converged)
# ML-NNI round 3: LogLk = -67208.533 NNIs 1 max delta 0.00 Time 5.99 (final)
# Optimize all lengths: LogLk = -67208.533 Time 6.23
# Total time: 7.32 seconds Unique: 11/11 Bad splits: 0/8

# %% [markdown]
# Finally, we can visualize the tree we just produce by pasting the contents of the file `clean.core.tree` in a visualizer tool such as [phyl.io](https://phylo.io/), or [iTOL](https://itol.embl.de/upload.cgi).
#
# The data we used may not be the best representation of differences in a phylogenetic tree as it comes from a single center outbreak and the samples may be highly similar among them.
