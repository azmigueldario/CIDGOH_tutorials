# %% [markdown]
# # Annotation of genomes
#
# Once we have analysis ready genomes (verified quality and lack of contamination), we can do annotation. The main goal of annotation is to identify the genomic features that are present in the analysis contigs. Usually, these tools use predictive algorithms (recognition of common sequences in the DNA) or alignment against a reference database to identify the different features of a genome.
#
# Bakta is a tool that produces a comprehensive annotation composed of Open Reading Frames (sequences that include codons for aminoacids of at least certain length), different types of RNA (ncRNA, tRNA, rRNA), hypothetical proteins, genes and CRISPR arrays.

# %%
# source PATH to use module function
source /cvmfs/soft.computecanada.ca/config/profile/bash.sh

# %% [markdown]
# Bakta uses a reference database that may be really large (~30GB). A reduced database of approximately 3.0 GB can be employed and will produce less specific results in feature annotation.
#
# We already downloaded the database using the command below and it is available in `/tools/reference_data/`
# ```
# singularity exec -B /scratch,/project,/etc </PATH/TO/BAKTA/IMAGE/> \
#     bakta_db download \
#     --output </OUTPUT/DIR/> \
#     --type light
# ```

# %% [markdown]
# We save the path to the bakta singularity image and reference dataset in the following way to provide it in the main pipeline.

# %%
BAKTA_IMG="/mnt/cidgoh-object-storage/images/bakta_1.7.sif"
export BAKTA_DB="/mnt/cidgoh-object-storage/database/bakta/db.tar.gz"

# %%
singularity exec -B /etc "$BAKTA_IMG" bakta \
    --db "$BAKTA_DB"                                                        `# path to bakta database` \
    /home/jupyter-mdprieto/tutorials/contigs/ERR10479518_contigs.fa         `# file to annotate`\
    --output /home/jupyter-mdprieto/tutorials/annotation/                   `# output directory` \
    --genus Pseudomonas                                                     `# specify genus of isolate` \
    --prefix $(echo "ERR10479518_contigs.fa" | grep -Eo "ERR[0-9]+")        `# prefix of sample name only for output`

# %% [markdown]
# Now, our analysis results look something like this. The directory structure now includes results from annotation and the tools directory includes a reference database to run the annotation.
#
# ```
# /home/jupyter-mdprieto
# |-- scripts
# |-- tools
# |   |-- reference_data
# |   `-- sing_imgs
# `-- tutorials
#     |-- annotation
#     |-- assembly_checkm
#     |-- assembly_quast
#     |-- contigs
#     |-- raw_reads
#     |-- results_qc
#     `-- trimmed_reads
# ```
#
# The output of **Bakta** annotation can be found in `tutorials/annotation`. Circular plots can be visualized by Jupyter by clicking them or exported to a local system. They may be partially incomplete as we are working with draft genomes instead of complete chromosome asssemblies or scaffolds. These more refined assemblies require long reads to polish the contigs.

# %% [markdown]
# # Phylogenetic tree
#
# To produce a phylogenetic tree we must compare the genomes using some kind of metric. Here, we will use **Snippy** to identify single nucleotide variants in our genomes and compare how different are these isolates between them.

# %%
SNIPPY_IMG="/home/jupyter-mdprieto/tools/sing_imgs/snippy_4.6.0.sif"
GUBBINS_IMG="/home/jupyter-mdprieto/tools/sing_imgs/gubbins-3.2.1.img"
CONTIGS_DIR="/home/jupyter-mdprieto/tutorials/contigs"
REF_GENOME="/home/jupyter-mdprieto/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna"

# %% [markdown]
# Snippy is a relatively fast tool, so we can analyze all the genomes we have available without too much wait. We apply the tool to every available draft genome. **Snippy** can also be used with raw reads and is actually the recommended use.

# %%
for contig in $(ls $HOME/tutorials/contigs/*contigs.fa)
do
    # define isolate name
    meta=$(basename "$contig" '_contigs.fa')

    # run snippy for each isolate
    singularity exec "$SNIPPY_IMG" snippy \
    --outdir "$HOME/tutorials/results_snippy/$meta"  `# save in a subdirectory`\
    --ctgs "$contig" \
    --ref $REF_GENOME \
    --cpus 8 \
    --force \
    --cleanup \
    --quiet

    # produce core genome analysis in results_snippy folder
    cd $HOME/tutorials/results_snippy/
    singularity exec "$SNIPPY_IMG" snippy-core --ref $REF_GENOME \
    /home/jupyter-mdprieto/tutorials/results_snippy/ERR*
done
# Out:
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [samclip] samclip 0.4.0 by Torsten Seemann (@torstenseemann)
# [samclip] Loading: reference/ref.fa.fai
# [samclip] Found 1 sequences in reference/ref.fa.fai
# [M::process] read 320000 sequences (80000000 bp)...
# [M::process] read 253774 sequences (63420526 bp)...
# [M::mem_process_seqs] Processed 320000 reads in 33.732 CPU sec, 4.157 real sec
# [samclip] Processed 100000 records...
# [samclip] Processed 200000 records...
# [samclip] Processed 300000 records...
# [M::mem_process_seqs] Processed 253774 reads in 29.132 CPU sec, 3.567 real sec
# [samclip] Processed 400000 records...
# [samclip] Processed 500000 records...
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa mem -Y -M -R @RG\tID:ERR10479510\tSM:ERR10479510 -t 8 reference/ref.fa fake_reads.fq
# [main] Real time: 9.843 sec; CPU: 64.386 sec
# [samclip] Total SAM records 574968, removed 9431, allowed 1610, passed 565537
# [samclip] Header contained 3 lines
# [samclip] Done.
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# normalize v0.5
#
# options:     input VCF file                                  -
#          [o] output VCF file                                 -
#          [w] sorting window size                             10000
#          [n] no fail on reference inconsistency for non SNPs false
#          [q] quiet                                           false
#          [d] debug                                           false
#          [r] reference FASTA file                            reference/ref.fa
#
#
# stats: biallelic
#           no. left trimmed                      : 57
#           no. right trimmed                     : 388
#           no. left and right trimmed            : 17
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. biallelic normalized           : 462
#
#        multiallelic
#           no. left trimmed                      : 0
#           no. right trimmed                     : 0
#           no. left and right trimmed            : 0
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. multiallelic normalized        : 0
#
#        total no. variants normalized            : 462
#        total no. variants observed              : 27311
#        total no. reference observed             : 0
#
# Time elapsed: 0.44s
#
# This is snippy-core 4.6.0
# Obtained from http://github.com/tseemann/snippy
# Enabling bundled tools for linux
# Found any2fasta - /usr/local/bin/any2fasta
# Found samtools - /usr/local/bin/samtools
# Found minimap2 - /usr/local/bin/minimap2
# Found bedtools - /usr/local/bin/bedtools
# Found snp-sites - /usr/local/bin/snp-sites
# Saving reference FASTA: core.ref.fa
# This is any2fasta 0.4.2
# Opening '/home/jupyter-mdprieto/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Detected FASTA format
# Read 78307 lines from '/home/jupyter-mdprieto/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Wrote 1 sequences from FASTA file.
# Processed 1 files.
# Done.
# Loaded 1 sequences totalling 6264404 bp.
# Will mask 0 regions totalling 0 bp ~ 0.00%
# 0	ERR10479510	snp=29320	del=604	ins=821	het=716	unaligned=305610
# 1	ERR10479511	snp=29300	del=642	ins=792	het=726	unaligned=309538
# Opening: core.tab
# Opening: core.vcf
# Processing contig: NC_002516.2
# Generating core.full.aln
# Creating TSV file: core.txt
# Running: snp-sites -c -o core.aln core.full.aln
# The Snippy manual is at http://github.com/tseemann/snippy/blob/master/README.md
# Done.
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [samclip] samclip 0.4.0 by Torsten Seemann (@torstenseemann)
# [samclip] Loading: reference/ref.fa.fai
# [samclip] Found 1 sequences in reference/ref.fa.fai
# [M::process] read 320000 sequences (80000000 bp)...
# [M::process] read 253688 sequences (63394572 bp)...
# [M::mem_process_seqs] Processed 320000 reads in 34.427 CPU sec, 4.251 real sec
# [samclip] Processed 100000 records...
# [samclip] Processed 200000 records...
# [samclip] Processed 300000 records...
# [M::mem_process_seqs] Processed 253688 reads in 31.425 CPU sec, 3.840 real sec
# [samclip] Processed 400000 records...
# [samclip] Processed 500000 records...
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa mem -Y -M -R @RG\tID:ERR10479511\tSM:ERR10479511 -t 8[samclip] Total SAM records 574979, removed 9845, allowed 1597, passed 565134
#  reference/ref.fa[samclip] Header contained 3 lines
#  fake_reads.fq[samclip] Done.
#
# [main] Real time: 9.807 sec; CPU: 67.019 sec
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# normalize v0.5
#
# options:     input VCF file                                  -
#          [o] output VCF file                                 -
#          [w] sorting window size                             10000
#          [n] no fail on reference inconsistency for non SNPs false
#          [q] quiet                                           false
#          [d] debug                                           false
#          [r] reference FASTA file                            reference/ref.fa
#
#
# stats: biallelic
#           no. left trimmed                      : 58
#           no. right trimmed                     : 390
#           no. left and right trimmed            : 18
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. biallelic normalized           : 466
#
#        multiallelic
#           no. left trimmed                      : 0
#           no. right trimmed                     : 0
#           no. left and right trimmed            : 0
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. multiallelic normalized        : 0
#
#        total no. variants normalized            : 466
#        total no. variants observed              : 27283
#        total no. reference observed             : 0
#
# Time elapsed: 0.44s
#
# This is snippy-core 4.6.0
# Obtained from http://github.com/tseemann/snippy
# Enabling bundled tools for linux
# Found any2fasta - /usr/local/bin/any2fasta
# Found samtools - /usr/local/bin/samtools
# Found minimap2 - /usr/local/bin/minimap2
# Found bedtools - /usr/local/bin/bedtools
# Found snp-sites - /usr/local/bin/snp-sites
# Saving reference FASTA: core.ref.fa
# This is any2fasta 0.4.2
# Opening '/home/jupyter-mdprieto/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Detected FASTA format
# Read 78307 lines from '/home/jupyter-mdprieto/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Wrote 1 sequences from FASTA file.
# Processed 1 files.
# Done.
# Loaded 1 sequences totalling 6264404 bp.
# Will mask 0 regions totalling 0 bp ~ 0.00%
# 0	ERR10479510	snp=29320	del=604	ins=821	het=716	unaligned=305610
# 1	ERR10479511	snp=29300	del=642	ins=792	het=726	unaligned=309538
# Opening: core.tab
# Opening: core.vcf
# Processing contig: NC_002516.2
# Generating core.full.aln
# Creating TSV file: core.txt
# Running: snp-sites -c -o core.aln core.full.aln
# Have a suggestion? Tell me at http://github.com/tseemann/snippy/issues
# Done.
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [samclip] samclip 0.4.0 by Torsten Seemann (@torstenseemann)
# [samclip] Loading: reference/ref.fa.fai
# [samclip] Found 1 sequences in reference/ref.fa.fai
# [M::process] read 320000 sequences (80000000 bp)...
# [M::process] read 253030 sequences (63239792 bp)...
# [M::mem_process_seqs] Processed 320000 reads in 33.697 CPU sec, 4.173 real sec
# [samclip] Processed 100000 records...
# [samclip] Processed 200000 records...
# [samclip] Processed 300000 records...
# [M::mem_process_seqs] Processed 253030 reads in 29.121 CPU sec, 3.567 real sec
# [samclip] Processed 400000 records...
# [samclip] Processed 500000 records...
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa mem -Y -M -R @RG\tID:ERR10479512\tSM:ERR10479512 -t 8 reference/ref.fa fake_reads.fq
# [main] Real time: 9.655 sec; CPU: 64.046 sec
# [samclip] Total SAM records 574186, removed 9514, allowed 1594, passed 564672
# [samclip] Header contained 3 lines
# [samclip] Done.
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# normalize v0.5
#
# options:     input VCF file                                  -
#          [o] output VCF file                                 -
#          [w] sorting window size                             10000
#          [n] no fail on reference inconsistency for non SNPs false
#          [q] quiet                                           false
#          [d] debug                                           false
#          [r] reference FASTA file                            reference/ref.fa
#
#
# stats: biallelic
#           no. left trimmed                      : 59
#           no. right trimmed                     : 386
#           no. left and right trimmed            : 19
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. biallelic normalized           : 464
#
#        multiallelic
#           no. left trimmed                      : 0
#           no. right trimmed                     : 0
#           no. left and right trimmed            : 0
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. multiallelic normalized        : 0
#
#        total no. variants normalized            : 464
#        total no. variants observed              : 27298
#        total no. reference observed             : 0
#
# Time elapsed: 0.43s
#
# This is snippy-core 4.6.0
# Obtained from http://github.com/tseemann/snippy
# Enabling bundled tools for linux
# Found any2fasta - /usr/local/bin/any2fasta
# Found samtools - /usr/local/bin/samtools
# Found minimap2 - /usr/local/bin/minimap2
# Found bedtools - /usr/local/bin/bedtools
# Found snp-sites - /usr/local/bin/snp-sites
# Saving reference FASTA: core.ref.fa
# This is any2fasta 0.4.2
# Opening '/home/jupyter-mdprieto/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Detected FASTA format
# Read 78307 lines from '/home/jupyter-mdprieto/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Wrote 1 sequences from FASTA file.
# Processed 1 files.
# Done.
# Loaded 1 sequences totalling 6264404 bp.
# Will mask 0 regions totalling 0 bp ~ 0.00%
# 0	ERR10479510	snp=29320	del=604	ins=821	het=716	unaligned=305610
# 1	ERR10479511	snp=29300	del=642	ins=792	het=726	unaligned=309538
# 2	ERR10479512	snp=29314	del=626	ins=792	het=711	unaligned=305996
# Opening: core.tab
# Opening: core.vcf
# Processing contig: NC_002516.2
# Generating core.full.aln
# Creating TSV file: core.txt
# Running: snp-sites -c -o core.aln core.full.aln
# Run 'snp-sites -b -c -o phylo.aln core.full.aln' for IQTree, BEAST, RaxML
# Done.
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [samclip] samclip 0.4.0 by Torsten Seemann (@torstenseemann)
# [samclip] Loading: reference/ref.fa.fai
# [samclip] Found 1 sequences in reference/ref.fa.fai
# [M::process] read 320000 sequences (80000000 bp)...
# [M::process] read 252942 sequences (63206218 bp)...
# [M::mem_process_seqs] Processed 320000 reads in 33.411 CPU sec, 4.121 real sec
# [samclip] Processed 100000 records...
# [samclip] Processed 200000 records...
# [samclip] Processed 300000 records...
# [M::mem_process_seqs] Processed 252942 reads in 28.998 CPU sec, 3.547 real sec
# [samclip] Processed 400000 records...
# [samclip] Processed 500000 records...
# [main] Version: 0.7.17-r1188
# [main] CMD:[samclip] Total SAM records 574178, removed 9556, allowed 1657, passed 564622
#  bwa mem[samclip] Header contained 3 lines
#  -Y[samclip] Done.
#  -M -R @RG\tID:ERR10479513\tSM:ERR10479513 -t 8 reference/ref.fa fake_reads.fq
# [main] Real time: 9.498 sec; CPU: 63.605 sec
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# normalize v0.5
#
# options:     input VCF file                                  -
#          [o] output VCF file                                 -
#          [w] sorting window size                             10000
#          [n] no fail on reference inconsistency for non SNPs false
#          [q] quiet                                           false
#          [d] debug                                           false
#          [r] reference FASTA file                            reference/ref.fa
#
#
# stats: biallelic
#           no. left trimmed                      : 58
#           no. right trimmed                     : 387
#           no. left and right trimmed            : 19
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. biallelic normalized           : 464
#
#        multiallelic
#           no. left trimmed                      : 0
#           no. right trimmed                     : 0
#           no. left and right trimmed            : 0
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. multiallelic normalized        : 0
#
#        total no. variants normalized            : 464
#        total no. variants observed              : 27315
#        total no. reference observed             : 0
#
# Time elapsed: 0.43s
#
# This is snippy-core 4.6.0
# Obtained from http://github.com/tseemann/snippy
# Enabling bundled tools for linux
# Found any2fasta - /usr/local/bin/any2fasta
# Found samtools - /usr/local/bin/samtools
# Found minimap2 - /usr/local/bin/minimap2
# Found bedtools - /usr/local/bin/bedtools
# Found snp-sites - /usr/local/bin/snp-sites
# Saving reference FASTA: core.ref.fa
# This is any2fasta 0.4.2
# Opening '/home/jupyter-mdprieto/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Detected FASTA format
# Read 78307 lines from '/home/jupyter-mdprieto/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Wrote 1 sequences from FASTA file.
# Processed 1 files.
# Done.
# Loaded 1 sequences totalling 6264404 bp.
# Will mask 0 regions totalling 0 bp ~ 0.00%
# 0	ERR10479510	snp=29320	del=604	ins=821	het=716	unaligned=305610
# 1	ERR10479511	snp=29300	del=642	ins=792	het=726	unaligned=309538
# 2	ERR10479512	snp=29314	del=626	ins=792	het=711	unaligned=305996
# 3	ERR10479513	snp=29345	del=627	ins=791	het=709	unaligned=305480
# Opening: core.tab
# Opening: core.vcf
# Processing contig: NC_002516.2
# Generating core.full.aln
# Creating TSV file: core.txt
# Running: snp-sites -c -o core.aln core.full.aln
# This analysis is totally hard-core!
# Done.
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [samclip] samclip 0.4.0 by Torsten Seemann (@torstenseemann)
# [samclip] Loading: reference/ref.fa.fai
# [samclip] Found 1 sequences in reference/ref.fa.fai
# [M::process] read 320000 sequences (80000000 bp)...
# [M::process] read 253342 sequences (63309110 bp)...
# [M::mem_process_seqs] Processed 320000 reads in 33.989 CPU sec, 4.212 real sec
# [samclip] Processed 100000 records...
# [samclip] Processed 200000 records...
# [samclip] Processed 300000 records...
# [M::mem_process_seqs] Processed 253342 reads in 31.448 CPU sec, 3.854 real sec
# [samclip] Processed 400000 records...
# [samclip] Processed 500000 records...
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa mem -Y -M -R[samclip] Total SAM records 574536, removed 9650, allowed 1603, passed 564886
# [samclip] Header contained 3 lines
#  @RG\tID:ERR10479514\tSM:ERR10479514 -t[samclip] Done.
#  8 reference/ref.fa fake_reads.fq
# [main] Real time: 10.488 sec; CPU: 67.025 sec
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# normalize v0.5
#
# options:     input VCF file                                  -
#          [o] output VCF file                                 -
#          [w] sorting window size                             10000
#          [n] no fail on reference inconsistency for non SNPs false
#          [q] quiet                                           false
#          [d] debug                                           false
#          [r] reference FASTA file                            reference/ref.fa
#
#
# stats: biallelic
#           no. left trimmed                      : 61
#           no. right trimmed                     : 393
#           no. left and right trimmed            : 18
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. biallelic normalized           : 472
#
#        multiallelic
#           no. left trimmed                      : 0
#           no. right trimmed                     : 0
#           no. left and right trimmed            : 0
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. multiallelic normalized        : 0
#
#        total no. variants normalized            : 472
#        total no. variants observed              : 27309
#        total no. reference observed             : 0
#
# Time elapsed: 0.45s
#
# This is snippy-core 4.6.0
# Obtained from http://github.com/tseemann/snippy
# Enabling bundled tools for linux
# Found any2fasta - /usr/local/bin/any2fasta
# Found samtools - /usr/local/bin/samtools
# Found minimap2 - /usr/local/bin/minimap2
# Found bedtools - /usr/local/bin/bedtools
# Found snp-sites - /usr/local/bin/snp-sites
# Saving reference FASTA: core.ref.fa
# This is any2fasta 0.4.2
# Opening '/home/jupyter-mdprieto/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Detected FASTA format
# Read 78307 lines from '/home/jupyter-mdprieto/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Wrote 1 sequences from FASTA file.
# Processed 1 files.
# Done.
# Loaded 1 sequences totalling 6264404 bp.
# Will mask 0 regions totalling 0 bp ~ 0.00%
# 0	ERR10479510	snp=29320	del=604	ins=821	het=716	unaligned=305610
# 1	ERR10479511	snp=29300	del=642	ins=792	het=726	unaligned=309538
# 2	ERR10479512	snp=29314	del=626	ins=792	het=711	unaligned=305996
# 3	ERR10479513	snp=29345	del=627	ins=791	het=709	unaligned=305480
# 4	ERR10479514	snp=29328	del=668	ins=794	het=694	unaligned=306415
# Opening: core.tab
# Opening: core.vcf
# Processing contig: NC_002516.2
# Generating core.full.aln
# Creating TSV file: core.txt
# Running: snp-sites -c -o core.aln core.full.aln
# Run 'snp-sites -b -c -o phylo.aln core.full.aln' for IQTree, BEAST, RaxML
# Done.
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [samclip] samclip 0.4.0 by Torsten Seemann (@torstenseemann)
# [samclip] Loading: reference/ref.fa.fai
# [samclip] Found 1 sequences in reference/ref.fa.fai
# [M::process] read 320000 sequences (80000000 bp)...
# [M::process] read 252588 sequences (63122680 bp)...
# [M::mem_process_seqs] Processed 320000 reads in 33.892 CPU sec, 4.174 real sec
# [samclip] Processed 100000 records...
# [samclip] Processed 200000 records...
# [samclip] Processed 300000 records...
# [M::mem_process_seqs] Processed 252588 reads in 28.847 CPU sec, 3.524 real sec
# [samclip] Processed 400000 records...
# [samclip] Processed 500000 records...
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa mem -Y -M -R @RG\tID:ERR10479515\tSM:ERR10479515 -t 8 reference/ref.fa fake_reads.fq
# [main] Real time: 9.457 sec; CPU: 63.969 sec
# [samclip] Total SAM records 573763, removed 9498, allowed 1571, passed 564265
# [samclip] Header contained 3 lines
# [samclip] Done.
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# normalize v0.5
#
# options:     input VCF file                                  -
#          [o] output VCF file                                 -
#          [w] sorting window size                             10000
#          [n] no fail on reference inconsistency for non SNPs false
#          [q] quiet                                           false
#          [d] debug                                           false
#          [r] reference FASTA file                            reference/ref.fa
#
#
# stats: biallelic
#           no. left trimmed                      : 57
#           no. right trimmed                     : 387
#           no. left and right trimmed            : 15
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. biallelic normalized           : 459
#
#        multiallelic
#           no. left trimmed                      : 0
#           no. right trimmed                     : 0
#           no. left and right trimmed            : 0
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. multiallelic normalized        : 0
#
#        total no. variants normalized            : 459
#        total no. variants observed              : 27299
#        total no. reference observed             : 0
#
# Time elapsed: 0.44s
#
# This is snippy-core 4.6.0
# Obtained from http://github.com/tseemann/snippy
# Enabling bundled tools for linux
# Found any2fasta - /usr/local/bin/any2fasta
# Found samtools - /usr/local/bin/samtools
# Found minimap2 - /usr/local/bin/minimap2
# Found bedtools - /usr/local/bin/bedtools
# Found snp-sites - /usr/local/bin/snp-sites
# Saving reference FASTA: core.ref.fa
# This is any2fasta 0.4.2
# Opening '/home/jupyter-mdprieto/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Detected FASTA format
# Read 78307 lines from '/home/jupyter-mdprieto/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Wrote 1 sequences from FASTA file.
# Processed 1 files.
# Done.
# Loaded 1 sequences totalling 6264404 bp.
# Will mask 0 regions totalling 0 bp ~ 0.00%
# 0	ERR10479510	snp=29320	del=604	ins=821	het=716	unaligned=305610
# 1	ERR10479511	snp=29300	del=642	ins=792	het=726	unaligned=309538
# 2	ERR10479512	snp=29314	del=626	ins=792	het=711	unaligned=305996
# 3	ERR10479513	snp=29345	del=627	ins=791	het=709	unaligned=305480
# 4	ERR10479514	snp=29328	del=668	ins=794	het=694	unaligned=306415
# 5	ERR10479515	snp=29315	del=603	ins=762	het=709	unaligned=306177
# Opening: core.tab
# Opening: core.vcf
# Processing contig: NC_002516.2
# Generating core.full.aln
# Creating TSV file: core.txt
# Running: snp-sites -c -o core.aln core.full.aln
# The Snippy manual is at http://github.com/tseemann/snippy/blob/master/README.md
# Done.
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [samclip] samclip 0.4.0 by Torsten Seemann (@torstenseemann)
# [samclip] Loading: reference/ref.fa.fai
# [samclip] Found 1 sequences in reference/ref.fa.fai
# [M::process] read 320000 sequences (80000000 bp)...
# [M::process] read 252052 sequences (62942802 bp)...
# [M::mem_process_seqs] Processed 320000 reads in 33.593 CPU sec, 4.145 real sec
# [samclip] Processed 100000 records...
# [samclip] Processed 200000 records...
# [samclip] Processed 300000 records...
# [M::mem_process_seqs] Processed 252052 reads in 28.349 CPU sec, 3.465 real sec
# [samclip] Processed 400000 records...
# [samclip] Processed 500000 records...
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa mem -Y -M -R @RG\tID:ERR10479516\tSM:ERR10479516 -t 8 reference/ref.fa fake_reads.fq
# [main] Real time: 9.745 sec; CPU: 63.403 sec
# [samclip] Total SAM records 573365, removed 9565, allowed 1648, passed 563800
# [samclip] Header contained 3 lines
# [samclip] Done.
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# normalize v0.5
#
# options:     input VCF file                                  -
#          [o] output VCF file                                 -
#          [w] sorting window size                             10000
#          [n] no fail on reference inconsistency for non SNPs false
#          [q] quiet                                           false
#          [d] debug                                           false
#          [r] reference FASTA file                            reference/ref.fa
#
#
# stats: biallelic
#           no. left trimmed                      : 55
#           no. right trimmed                     : 386
#           no. left and right trimmed            : 18
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. biallelic normalized           : 459
#
#        multiallelic
#           no. left trimmed                      : 0
#           no. right trimmed                     : 0
#           no. left and right trimmed            : 0
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. multiallelic normalized        : 0
#
#        total no. variants normalized            : 459
#        total no. variants observed              : 27283
#        total no. reference observed             : 0
#
# Time elapsed: 0.47s
#
# This is snippy-core 4.6.0
# Obtained from http://github.com/tseemann/snippy
# Enabling bundled tools for linux
# Found any2fasta - /usr/local/bin/any2fasta
# Found samtools - /usr/local/bin/samtools
# Found minimap2 - /usr/local/bin/minimap2
# Found bedtools - /usr/local/bin/bedtools
# Found snp-sites - /usr/local/bin/snp-sites
# Saving reference FASTA: core.ref.fa
# This is any2fasta 0.4.2
# Opening '/home/jupyter-mdprieto/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Detected FASTA format
# Read 78307 lines from '/home/jupyter-mdprieto/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Wrote 1 sequences from FASTA file.
# Processed 1 files.
# Done.
# Loaded 1 sequences totalling 6264404 bp.
# Will mask 0 regions totalling 0 bp ~ 0.00%
# 0	ERR10479510	snp=29320	del=604	ins=821	het=716	unaligned=305610
# 1	ERR10479511	snp=29300	del=642	ins=792	het=726	unaligned=309538
# 2	ERR10479512	snp=29314	del=626	ins=792	het=711	unaligned=305996
# 3	ERR10479513	snp=29345	del=627	ins=791	het=709	unaligned=305480
# 4	ERR10479514	snp=29328	del=668	ins=794	het=694	unaligned=306415
# 5	ERR10479515	snp=29315	del=603	ins=762	het=709	unaligned=306177
# 6	ERR10479516	snp=29293	del=622	ins=792	het=775	unaligned=305541
# Opening: core.tab
# Opening: core.vcf
# Processing contig: NC_002516.2
# Generating core.full.aln
# Creating TSV file: core.txt
# Running: snp-sites -c -o core.aln core.full.aln
# The Snippy manual is at http://github.com/tseemann/snippy/blob/master/README.md
# Done.
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [samclip] samclip 0.4.0 by Torsten Seemann (@torstenseemann)
# [samclip] Loading: reference/ref.fa.fai
# [samclip] Found 1 sequences in reference/ref.fa.fai
# [M::process] read 320000 sequences (80000000 bp)...
# [M::process] read 252422 sequences (63033870 bp)...
# [M::mem_process_seqs] Processed 320000 reads in 34.936 CPU sec, 4.317 real sec
# [samclip] Processed 100000 records...
# [samclip] Processed 200000 records...
# [samclip] Processed 300000 records...
# [M::mem_process_seqs] Processed 252422 reads in 30.570 CPU sec, 3.726 real sec
# [samclip] Processed 400000 records...
# [samclip] Processed 500000 records...
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa mem -Y -M -R[samclip] Total SAM records 573735, removed 9500, allowed 1661, passed 564235
# [samclip] Header contained 3 lines
#  @RG\tID:ERR10479517\tSM:ERR10479517 -t[samclip] Done.
#  8 reference/ref.fa fake_reads.fq
# [main] Real time: 9.956 sec; CPU: 66.890 sec
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# normalize v0.5
#
# options:     input VCF file                                  -
#          [o] output VCF file                                 -
#          [w] sorting window size                             10000
#          [n] no fail on reference inconsistency for non SNPs false
#          [q] quiet                                           false
#          [d] debug                                           false
#          [r] reference FASTA file                            reference/ref.fa
#
#
# stats: biallelic
#           no. left trimmed                      : 56
#           no. right trimmed                     : 386
#           no. left and right trimmed            : 18
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. biallelic normalized           : 460
#
#        multiallelic
#           no. left trimmed                      : 0
#           no. right trimmed                     : 0
#           no. left and right trimmed            : 0
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. multiallelic normalized        : 0
#
#        total no. variants normalized            : 460
#        total no. variants observed              : 27305
#        total no. reference observed             : 0
#
# Time elapsed: 0.44s
#
# This is snippy-core 4.6.0
# Obtained from http://github.com/tseemann/snippy
# Enabling bundled tools for linux
# Found any2fasta - /usr/local/bin/any2fasta
# Found samtools - /usr/local/bin/samtools
# Found minimap2 - /usr/local/bin/minimap2
# Found bedtools - /usr/local/bin/bedtools
# Found snp-sites - /usr/local/bin/snp-sites
# Saving reference FASTA: core.ref.fa
# This is any2fasta 0.4.2
# Opening '/home/jupyter-mdprieto/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Detected FASTA format
# Read 78307 lines from '/home/jupyter-mdprieto/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Wrote 1 sequences from FASTA file.
# Processed 1 files.
# Done.
# Loaded 1 sequences totalling 6264404 bp.
# Will mask 0 regions totalling 0 bp ~ 0.00%
# 0	ERR10479510	snp=29320	del=604	ins=821	het=716	unaligned=305610
# 1	ERR10479511	snp=29300	del=642	ins=792	het=726	unaligned=309538
# 2	ERR10479512	snp=29314	del=626	ins=792	het=711	unaligned=305996
# 3	ERR10479513	snp=29345	del=627	ins=791	het=709	unaligned=305480
# 4	ERR10479514	snp=29328	del=668	ins=794	het=694	unaligned=306415
# 5	ERR10479515	snp=29315	del=603	ins=762	het=709	unaligned=306177
# 6	ERR10479516	snp=29293	del=622	ins=792	het=775	unaligned=305541
# 7	ERR10479517	snp=29336	del=637	ins=792	het=726	unaligned=305577
# Opening: core.tab
# Opening: core.vcf
# Processing contig: NC_002516.2
# Generating core.full.aln
# Creating TSV file: core.txt
# Running: snp-sites -c -o core.aln core.full.aln
# Run 'snp-sites -b -c -o phylo.aln core.full.aln' for IQTree, BEAST, RaxML
# Done.
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [samclip] samclip 0.4.0 by Torsten Seemann (@torstenseemann)
# [samclip] Loading: reference/ref.fa.fai
# [samclip] Found 1 sequences in reference/ref.fa.fai
# [M::process] read 320000 sequences (80000000 bp)...
# [M::process] read 265630 sequences (66341968 bp)...
# [M::mem_process_seqs] Processed 320000 reads in 33.658 CPU sec, 4.131 real sec
# [samclip] Processed 100000 records...
# [samclip] Processed 200000 records...
# [samclip] Processed 300000 records...
# [M::mem_process_seqs] Processed 265630 reads in 31.763 CPU sec, 3.880 real sec
# [samclip] Processed 400000 records...
# [samclip] Processed 500000 records...
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa mem -Y -M -R @RG\tID:ERR10479518\tSM:ERR10479518 -t 8 reference/ref.fa fake_reads.fq[samclip] Total SAM records 586987, removed 9619, allowed 1635, passed 577368
#
# [main] Real time: 10.016 sec; CPU: 66.788 sec
# [samclip] Header contained 3 lines
# [samclip] Done.
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# normalize v0.5
#
# options:     input VCF file                                  -
#          [o] output VCF file                                 -
#          [w] sorting window size                             10000
#          [n] no fail on reference inconsistency for non SNPs false
#          [q] quiet                                           false
#          [d] debug                                           false
#          [r] reference FASTA file                            reference/ref.fa
#
#
# stats: biallelic
#           no. left trimmed                      : 57
#           no. right trimmed                     : 384
#           no. left and right trimmed            : 18
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. biallelic normalized           : 459
#
#        multiallelic
#           no. left trimmed                      : 0
#           no. right trimmed                     : 0
#           no. left and right trimmed            : 0
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. multiallelic normalized        : 0
#
#        total no. variants normalized            : 459
#        total no. variants observed              : 27292
#        total no. reference observed             : 0
#
# Time elapsed: 0.44s
#
# This is snippy-core 4.6.0
# Obtained from http://github.com/tseemann/snippy
# Enabling bundled tools for linux
# Found any2fasta - /usr/local/bin/any2fasta
# Found samtools - /usr/local/bin/samtools
# Found minimap2 - /usr/local/bin/minimap2
# Found bedtools - /usr/local/bin/bedtools
# Found snp-sites - /usr/local/bin/snp-sites
# Saving reference FASTA: core.ref.fa
# This is any2fasta 0.4.2
# Opening '/home/jupyter-mdprieto/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Detected FASTA format
# Read 78307 lines from '/home/jupyter-mdprieto/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Wrote 1 sequences from FASTA file.
# Processed 1 files.
# Done.
# Loaded 1 sequences totalling 6264404 bp.
# Will mask 0 regions totalling 0 bp ~ 0.00%
# 0	ERR10479510	snp=29320	del=604	ins=821	het=716	unaligned=305610
# 1	ERR10479511	snp=29300	del=642	ins=792	het=726	unaligned=309538
# 2	ERR10479512	snp=29314	del=626	ins=792	het=711	unaligned=305996
# 3	ERR10479513	snp=29345	del=627	ins=791	het=709	unaligned=305480
# 4	ERR10479514	snp=29328	del=668	ins=794	het=694	unaligned=306415
# 5	ERR10479515	snp=29315	del=603	ins=762	het=709	unaligned=306177
# 6	ERR10479516	snp=29293	del=622	ins=792	het=775	unaligned=305541
# 7	ERR10479517	snp=29336	del=637	ins=792	het=726	unaligned=305577
# 8	ERR10479518	snp=29321	del=607	ins=777	het=742	unaligned=305529
# Opening: core.tab
# Opening: core.vcf
# Processing contig: NC_002516.2
# Generating core.full.aln
# Creating TSV file: core.txt
# Running: snp-sites -c -o core.aln core.full.aln
# This analysis is totally hard-core!
# Done.
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [samclip] samclip 0.4.0 by Torsten Seemann (@torstenseemann)
# [samclip] Loading: reference/ref.fa.fai
# [samclip] Found 1 sequences in reference/ref.fa.fai
# [M::process] read 320000 sequences (80000000 bp)...
# [M::process] read 252874 sequences (63131650 bp)...
# [M::mem_process_seqs] Processed 320000 reads in 33.673 CPU sec, 4.153 real sec
# [samclip] Processed 100000 records...
# [samclip] Processed 200000 records...
# [samclip] Processed 300000 records...
# [M::mem_process_seqs] Processed 252874 reads in 29.220 CPU sec, 3.567 real sec
# [samclip] Processed 400000 records...
# [samclip] Processed 500000 records...
# [main] Version: 0.7.17-r1188
# [main] CMD: bwa mem -Y -M -R @RG\tID:ERR10479519\tSM:ERR10479519 -t 8 reference/ref.fa fake_reads.fq[samclip] Total SAM records 574230, removed 9558, allowed 1557, passed 564672
#
# [main] Real time: 9.765 sec; CPU: 64.086 sec
# [samclip] Header contained 3 lines
# [samclip] Done.
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# [bam_sort_core] merging from 0 files and 3 in-memory blocks...
# normalize v0.5
#
# options:     input VCF file                                  -
#          [o] output VCF file                                 -
#          [w] sorting window size                             10000
#          [n] no fail on reference inconsistency for non SNPs false
#          [q] quiet                                           false
#          [d] debug                                           false
#          [r] reference FASTA file                            reference/ref.fa
#
#
# stats: biallelic
#           no. left trimmed                      : 56
#           no. right trimmed                     : 388
#           no. left and right trimmed            : 17
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. biallelic normalized           : 461
#
#        multiallelic
#           no. left trimmed                      : 0
#           no. right trimmed                     : 0
#           no. left and right trimmed            : 0
#           no. right trimmed and left aligned    : 0
#           no. left aligned                      : 0
#
#        total no. multiallelic normalized        : 0
#
#        total no. variants normalized            : 461
#        total no. variants observed              : 27292
#        total no. reference observed             : 0
#
# Time elapsed: 0.43s
#
# This is snippy-core 4.6.0
# Obtained from http://github.com/tseemann/snippy
# Enabling bundled tools for linux
# Found any2fasta - /usr/local/bin/any2fasta
# Found samtools - /usr/local/bin/samtools
# Found minimap2 - /usr/local/bin/minimap2
# Found bedtools - /usr/local/bin/bedtools
# Found snp-sites - /usr/local/bin/snp-sites
# Saving reference FASTA: core.ref.fa
# This is any2fasta 0.4.2
# Opening '/home/jupyter-mdprieto/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Detected FASTA format
# Read 78307 lines from '/home/jupyter-mdprieto/tools/reference_data/GCF_000006765.1_ASM676v1_genomic.fna'
# Wrote 1 sequences from FASTA file.
# Processed 1 files.
# Done.
# Loaded 1 sequences totalling 6264404 bp.
# Will mask 0 regions totalling 0 bp ~ 0.00%
# 0	ERR10479510	snp=29320	del=604	ins=821	het=716	unaligned=305610
# 1	ERR10479511	snp=29300	del=642	ins=792	het=726	unaligned=309538
# 2	ERR10479512	snp=29314	del=626	ins=792	het=711	unaligned=305996
# 3	ERR10479513	snp=29345	del=627	ins=791	het=709	unaligned=305480
# 4	ERR10479514	snp=29328	del=668	ins=794	het=694	unaligned=306415
# 5	ERR10479515	snp=29315	del=603	ins=762	het=709	unaligned=306177
# 6	ERR10479516	snp=29293	del=622	ins=792	het=775	unaligned=305541
# 7	ERR10479517	snp=29336	del=637	ins=792	het=726	unaligned=305577
# 8	ERR10479518	snp=29321	del=607	ins=777	het=742	unaligned=305529
# 9	ERR10479519	snp=29311	del=664	ins=774	het=725	unaligned=306694
# Opening: core.tab
# Opening: core.vcf
# Processing contig: NC_002516.2
# Generating core.full.aln
# Creating TSV file: core.txt
# Running: snp-sites -c -o core.aln core.full.aln
# This analysis is totally hard-core!
# Done.

# %% [markdown]
# Once we have the data from the snippy call, we run a few additional steps to clean our results and to have them ready for phylogenetic analysis.
#
# 1. We run **snippy-core** to make a summary of SNV found in genes that are common to all isolates analyzed
# 2. We run another tool, **Gubbins**, that eliminates features that are known to be transmitted through horizontal gene transfer. As the variability in these may come from other bacteria in the environment, they are not useful for phylogenetic analysis.
# 3. Once we have the cleaned alignment, we use **snp-sites** to

# %%
cd $HOME/tutorials/results_snippy

# clean file
singularity exec $SNIPPY_IMG snippy-clean_full_aln core.full.aln > clean.full.aln

# gubbins remove horizontal gene transfer 
singularity exec $GUBBINS_IMG run_gubbins.py -p gubbins clean.full.aln

# SNP-sites
singularity exec $SNIPPY_IMG snp-sites -c gubbins.filtered_polymorphic_sites.fasta > clean.core.aln

# produce tree
$HOME/tools/FastTree -gtr -nt clean.core.aln > clean.core.tree

# %% [markdown]
# Finally, we can visualize the tree we just produce by pasting the contents of the file `clean.core.tree` in a visualizer tool such as [phyl.io](https://phylo.io/), or [iTOL](https://itol.embl.de/upload.cgi).
#
# The data we used may not be the best representation of differences in a phylogenetic tree as it comes from a single center outbreak and the samples were collected close to each other. Another issue may be that the reference genome employed was not adequate and thus, it is not showing significant differences.

# %%
cd $CONTIGS_DIR
readlink -f *contigs.fa > path.txt
cat path.txt | sed -s "s/_contigs.fa//" | sed -s 's/contigs/results_snippy/' > filenames.txt


# join them and remove temp files
paste filenames.txt path.txt > ~/scripts/snippy-input.tab
rm filenames.txt path.txt
